# %% [markdown]
# <a href="https://colab.research.google.com/github/olivia-sp/study-pjt/blob/main/CRAFT_license_plate_data_fine_tuning_v0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CRAFT License Plate Detection Fine-Tuning
# 1.   get_licenseplate_detector_dataset 라는 licnese plate detection data에 대한 정보를 return하는 함수를 새로 작성 (Reference : https://github.com/faustomorales/keras-ocr/blob/master/keras_ocr/datasets.py#L178 )
# 2.   license plate detector 데이터셋에 맞게 CRAFT 파라미터 Fine-Tuning

# %% [markdown]
# ##환경설정

# %%
# Install this package to use Colab's GPU for training
# !apt install --allow-change-held-packages libcudnn8=8.4.1.50-1+cuda11.6
# Out:
# Fetched 420 MB in 7s (62.3 MB/s)
# (Reading database ... 123942 files and directories currently installed.)
# Removing libcudnn8-dev (8.1.1.33-1+cuda11.2) ...
# update-alternatives: removing manually selected alternative - switching libcudnn to auto mode
# (Reading database ... 123919 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.4.1.50-1+cuda11.6_amd64.deb ...
# Unpacking libcudnn8 (8.4.1.50-1+cuda11.6) over (8.1.1.33-1+cuda11.2) ...
# Setting up libcudnn8 (8.4.1.50-1+cuda11.6) ...

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
# !pip install keras-ocr
# Out:
# Installing collected packages: keras-applications, validators, pyclipper, fonttools, essential-generators, efficientnet, keras-ocr
# Successfully installed efficientnet-1.0.0 essential-generators-1.0 fonttools-4.38.0 keras-applications-1.0.8 keras-ocr-0.9.1 pyclipper-1.3.0.post3 validators-0.20.0

# %%
# !pip install opencv-python-headless
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless) (1.21.6)

# %% [markdown]
# ### Training을 위한 기존 데이터셋 다운로드

# %% [markdown]
# license_plate_dataset
# - Reference : https://drive.google.com/file/d/1gvD8rsMNFGtu1VxKTwz3_2tQrhE8d9SV/view?usp=sharing

# %%
data_dir = '.'

import os
import math
import imgaug
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection
import tensorflow as tf

import keras_ocr

dataset = keras_ocr.datasets.get_icdar_2013_detector_dataset(
    cache_dir='.',
    skip_illegible=False
)
# Out:
# Looking for ./icdar2013/Challenge2_Training_Task12_Images.zip
# Downloading ./icdar2013/Challenge2_Training_Task12_Images.zip
# Looking for ./icdar2013/Challenge2_Training_Task2_GT.zip
# Downloading ./icdar2013/Challenge2_Training_Task2_GT.zip

# %%
dataset
# Out:
# [('./icdar2013/Challenge2_Training_Task12_Images/303.jpg',
#   [[(array([[1198, 1212],
#             [1330, 1212],
#             [1330, 1339],
#             [1198, 1339]]), 'p'), (array([[1341, 1211],
#             [1418, 1211],
#             [1418, 1301],
#             [1341, 1301]]), 'r'), (array([[1428, 1179],
#             [1467, 1179],
#             [1467, 1300],
#             [1428, 1300]]), 'i'), (array([[1474, 1210],
#             [1595, 1210],
#             [1595, 1300],
#             [1474, 1300]]), 'v'), (array([[1600, 1179],
#             [1639, 1179],
#             [1639, 1299],
#             [1600, 1299]]), 'i'), (array([[1652, 1178],
#             [1691, 1178],
#             [1691, 1298],
#             [1652, 1298]]), 'l'), (array([[1705, 1209],
#             [1827, 1209],
#             [1827, 1298],
#             [1705, 1298]]), 'e'), (array([[1840, 1209],
#             [1964, 1209],
#             [1964, 1333],
#             [1840, 1333]]), 'g')], [(array([[2038, 1177],
#             [2125, 1177],
#             [2125, 1296],
#             [2038, 1296]]), '8'), (array([[2137, 1176],
#             [2231, 1176],
#             [2231, 1295],
#             [2137, 1295]]), '0'), (array([[2252, 1181],
#             [2297, 1181],
#             [2297, 1291],
#             [2252, 1291]]), '1'), (array([[2318, 1181],
#             [2419, 1181],
#             [2419, 1290],
#             [2318, 1290]]), '7')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/324.jpg',
#   [[(array([[1415, 1275],
#             [1754, 1275],
#             [1754, 2071],
#             [1415, 2071]]), 'F'), (array([[1674, 1291],
#             [2154, 1291],
#             [2154, 2082],
#             [1674, 2082]]), 'A'), (array([[2155, 1294],
#             [2336, 1294],
#             [2336, 2082],
#             [2155, 2082]]), 'I'), (array([[2353, 1292],
#             [2772, 1292],
#             [2772, 2077],
#             [2353, 2077]]), 'R'), (array([[2716, 1258],
#             [3141, 1258],
#             [3141, 2050],
#             [2716, 2050]]), 'Y')], [(array([[1540, 2196],
#             [1811, 2196],
#             [1811, 2448],
#             [1540, 2448]]), 'E'), (array([[1766, 2241],
#             [2091, 2241],
#             [2091, 2454],
#             [1766, 2454]]), 'X'), (array([[2060, 2245],
#             [2310, 2245],
#             [2310, 2454],
#             [2060, 2454]]), 'P'), (array([[2293, 2231],
#             [2515, 2231],
#             [2515, 2447],
#             [2293, 2447]]), 'E'), (array([[2498, 2222],
#             [2734, 2222],
#             [2734, 2443],
#             [2498, 2443]]), 'R'), (array([[2739, 2210],
#             [2900, 2210],
#             [2900, 2425],
#             [2739, 2425]]), 'T')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/106.jpg',
#   [[(array([[199, 175],
#             [209, 175],
#             [209, 203],
#             [199, 203]]), 'I'), (array([[211, 181],
#             [236, 181],
#             [236, 203],
#             [211, 203]]), 'n'), (array([[242, 175],
#             [258, 175],
#             [258, 203],
#             [242, 203]]), 'f'), (array([[260, 182],
#             [287, 182],
#             [287, 204],
#             [260, 204]]), 'o'), (array([[292, 182],
#             [308, 182],
#             [308, 204],
#             [292, 204]]), 'r'), (array([[312, 182],
#             [350, 182],
#             [350, 205],
#             [312, 205]]), 'm'), (array([[356, 183],
#             [382, 183],
#             [382, 206],
#             [356, 206]]), 'a'), (array([[387, 177],
#             [404, 177],
#             [404, 206],
#             [387, 206]]), 't'), (array([[408, 177],
#             [415, 177],
#             [415, 206],
#             [408, 206]]), 'i'), (array([[420, 184],
#             [447, 184],
#             [447, 206],
#             [420, 206]]), 'o'), (array([[451, 184],
#             [477, 184],
#             [477, 206],
#             [451, 206]]), 'n')], [(array([[296, 233],
#             [324, 233],
#             [324, 265],
#             [296, 265]]), 'T'), (array([[327, 233],
#             [334, 233],
#             [334, 266],
#             [327, 266]]), 'i'), (array([[339, 241],
#             [367, 241],
#             [367, 267],
#             [339, 267]]), 'c'), (array([[372, 234],
#             [400, 234],
#             [400, 266],
#             [372, 266]]), 'k'), (array([[403, 241],
#             [431, 241],
#             [431, 267],
#             [403, 267]]), 'e'), (array([[434, 235],
#             [453, 235],
#             [453, 267],
#             [434, 267]]), 't'), (array([[457, 242],
#             [484, 242],
#             [484, 267],
#             [457, 267]]), 's')], [(array([[331, 298],
#             [361, 298],
#             [361, 334],
#             [331, 334]]), 'T'), (array([[361, 306],
#             [378, 306],
#             [378, 334],
#             [361, 334]]), 'r'), (array([[382, 306],
#             [412, 306],
#             [412, 335],
#             [382, 335]]), 'a'), (array([[416, 298],
#             [426, 298],
#             [426, 334],
#             [416, 334]]), 'i'), (array([[430, 306],
#             [459, 306],
#             [459, 334],
#             [430, 334]]), 'n'), (array([[463, 306],
#             [492, 306],
#             [492, 335],
#             [463, 335]]), 's')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/244.jpg',
#   [[(array([[289, 174],
#             [309, 174],
#             [309, 198],
#             [289, 198]]), 'C'), (array([[316, 180],
#             [333, 180],
#             [333, 196],
#             [316, 196]]), 'a'), (array([[342, 180],
#             [355, 180],
#             [355, 195],
#             [342, 195]]), 'n'), (array([[363, 179],
#             [377, 179],
#             [377, 196],
#             [363, 196]]), 'o'), (array([[385, 180],
#             [400, 180],
#             [400, 194],
#             [385, 194]]), 'n')], [(array([[211, 212],
#             [272, 212],
#             [272, 253],
#             [211, 253]]), 'P'), (array([[247, 236],
#             [272, 236],
#             [272, 254],
#             [247, 254]]), 'o'), (array([[276, 238],
#             [309, 238],
#             [309, 253],
#             [276, 253]]), 'w'), (array([[309, 237],
#             [333, 237],
#             [333, 255],
#             [309, 255]]), 'e'), (array([[336, 238],
#             [353, 238],
#             [353, 254],
#             [336, 254]]), 'r'), (array([[354, 216],
#             [396, 216],
#             [396, 255],
#             [354, 255]]), 'S'), (array([[394, 231],
#             [418, 231],
#             [418, 255],
#             [394, 255]]), 'h'), (array([[422, 239],
#             [446, 239],
#             [446, 258],
#             [422, 258]]), 'o'), (array([[451, 237],
#             [464, 237],
#             [464, 257],
#             [451, 257]]), 't')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/279.jpg',
#   [[(array([[ 63,  61],
#             [149,  61],
#             [149, 168],
#             [ 63, 168]]), '')], [(array([[169,  75],
#             [246,  75],
#             [246, 166],
#             [169, 166]]), '')], [(array([[251,  65],
#             [309,  65],
#             [309, 141],
#             [251, 141]]), '')], [(array([[346,  56],
#             [429,  56],
#             [429, 162],
#             [346, 162]]), '')], [(array([[496,  57],
#             [586,  57],
#             [586, 157],
#             [496, 157]]), '')], [(array([[ 26, 190],
#             [132, 190],
#             [132, 322],
#             [ 26, 322]]), 'S'), (array([[156, 191],
#             [248, 191],
#             [248, 311],
#             [156, 311]]), 'T'), (array([[226, 210],
#             [319, 210],
#             [319, 323],
#             [226, 323]]), 'U'), (array([[340, 191],
#             [440, 191],
#             [440, 321],
#             [340, 321]]), 'D'), (array([[462, 195],
#             [506, 195],
#             [506, 320],
#             [462, 320]]), 'I'), (array([[522, 196],
#             [624, 196],
#             [624, 320],
#             [522, 320]]), 'O')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/202.jpg',
#   [[(array([[  3, 147],
#             [ 24, 147],
#             [ 24, 179],
#             [  3, 179]]), 'A'), (array([[ 32, 146],
#             [ 52, 146],
#             [ 52, 179],
#             [ 32, 179]]), 'R'), (array([[ 60, 145],
#             [ 79, 145],
#             [ 79, 179],
#             [ 60, 179]]), 'E'), (array([[ 87, 143],
#             [108, 143],
#             [108, 179],
#             [ 87, 179]]), 'N'), (array([[114, 142],
#             [138, 142],
#             [138, 178],
#             [114, 178]]), 'A')], [(array([[166, 143],
#             [187, 143],
#             [187, 177],
#             [166, 177]]), 'L'), (array([[194, 142],
#             [214, 142],
#             [214, 177],
#             [194, 177]]), 'E'), (array([[225, 142],
#             [228, 142],
#             [228, 177],
#             [225, 177]]), 'I'), (array([[239, 141],
#             [259, 141],
#             [259, 177],
#             [239, 177]]), 'S'), (array([[268, 141],
#             [290, 141],
#             [290, 177],
#             [268, 177]]), 'U'), (array([[299, 140],
#             [323, 140],
#             [323, 176],
#             [299, 176]]), 'R'), (array([[331, 140],
#             [351, 140],
#             [351, 175],
#             [331, 175]]), 'E')], [(array([[383, 139],
#             [404, 139],
#             [404, 175],
#             [383, 175]]), 'S'), (array([[413, 139],
#             [435, 139],
#             [435, 175],
#             [413, 175]]), 'E'), (array([[445, 138],
#             [469, 138],
#             [469, 174],
#             [445, 174]]), 'R'), (array([[475, 138],
#             [500, 138],
#             [500, 174],
#             [475, 174]]), 'V'), (array([[510, 137],
#             [514, 137],
#             [514, 174],
#             [510, 174]]), 'I'), (array([[524, 137],
#             [547, 137],
#             [547, 174],
#             [524, 174]]), 'C'), (array([[555, 137],
#             [577, 137],
#             [577, 173],
#             [555, 173]]), 'E'), (array([[587, 137],
#             [608, 137],
#             [608, 173],
#             [587, 173]]), 'S')], [(array([[203, 217],
#             [223, 217],
#             [223, 252],
#             [203, 252]]), 'L'), (array([[232, 217],
#             [236, 217],
#             [236, 252],
#             [232, 252]]), 'I'), (array([[247, 215],
#             [275, 215],
#             [275, 253],
#             [247, 253]]), 'M'), (array([[286, 216],
#             [289, 216],
#             [289, 252],
#             [286, 252]]), 'I'), (array([[299, 217],
#             [323, 217],
#             [323, 252],
#             [299, 252]]), 'T'), (array([[330, 217],
#             [351, 217],
#             [351, 252],
#             [330, 252]]), 'E'), (array([[361, 216],
#             [384, 216],
#             [384, 252],
#             [361, 252]]), 'D')], [(array([[123, 294],
#             [144, 294],
#             [144, 328],
#             [123, 328]]), 'R'), (array([[151, 304],
#             [164, 304],
#             [164, 329],
#             [151, 329]]), 'e'), (array([[170, 299],
#             [187, 299],
#             [187, 337],
#             [170, 337]]), 'g'), (array([[195, 294],
#             [198, 294],
#             [198, 329],
#             [195, 329]]), 'i'), (array([[205, 304],
#             [218, 304],
#             [218, 329],
#             [205, 329]]), 's'), (array([[223, 296],
#             [236, 296],
#             [236, 330],
#             [223, 330]]), 't'), (array([[242, 304],
#             [256, 304],
#             [256, 330],
#             [242, 330]]), 'e'), (array([[262, 303],
#             [275, 303],
#             [275, 330],
#             [262, 330]]), 'r'), (array([[281, 304],
#             [296, 304],
#             [296, 330],
#             [281, 330]]), 'e'), (array([[301, 293],
#             [315, 293],
#             [315, 331],
#             [301, 331]]), 'd')], [(array([[345, 293],
#             [369, 293],
#             [369, 332],
#             [345, 332]]), 'O'), (array([[376, 294],
#             [392, 294],
#             [392, 331],
#             [376, 331]]), 'f'), (array([[398, 294],
#             [414, 294],
#             [414, 331],
#             [398, 331]]), 'f'), (array([[422, 295],
#             [425, 295],
#             [425, 331],
#             [422, 331]]), 'i'), (array([[433, 305],
#             [448, 305],
#             [448, 332],
#             [433, 332]]), 'c'), (array([[453, 305],
#             [468, 305],
#             [468, 332],
#             [453, 332]]), 'e')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/251.jpg',
#   [[(array([[ 97, 217],
#             [153, 217],
#             [153, 287],
#             [ 97, 287]]), 'N'), (array([[166, 217],
#             [176, 217],
#             [176, 287],
#             [166, 287]]), 'i'), (array([[185, 239],
#             [230, 239],
#             [230, 309],
#             [185, 309]]), 'g'), (array([[243, 217],
#             [281, 217],
#             [281, 287],
#             [243, 287]]), 'h'), (array([[290, 226],
#             [314, 226],
#             [314, 289],
#             [290, 289]]), 't'), (array([[323, 218],
#             [331, 218],
#             [331, 288],
#             [323, 288]]), 'l'), (array([[344, 218],
#             [351, 218],
#             [351, 288],
#             [344, 288]]), 'i'), (array([[364, 240],
#             [402, 240],
#             [402, 288],
#             [364, 288]]), 'n'), (array([[414, 240],
#             [457, 240],
#             [457, 290],
#             [414, 290]]), 'e')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/210.jpg',
#   [[(array([[122, 194],
#             [157, 194],
#             [157, 245],
#             [122, 245]]), 'R'), (array([[157, 194],
#             [187, 194],
#             [187, 245],
#             [157, 245]]), 'E'), (array([[190, 192],
#             [218, 192],
#             [218, 246],
#             [190, 246]]), 'S'), (array([[222, 193],
#             [249, 193],
#             [249, 244],
#             [222, 244]]), 'E'), (array([[253, 193],
#             [285, 193],
#             [285, 244],
#             [253, 244]]), 'R'), (array([[284, 192],
#             [321, 192],
#             [321, 243],
#             [284, 243]]), 'V'), (array([[324, 191],
#             [349, 191],
#             [349, 242],
#             [324, 242]]), 'E'), (array([[355, 191],
#             [389, 191],
#             [389, 242],
#             [355, 242]]), 'D')], [(array([[413, 190],
#             [440, 190],
#             [440, 240],
#             [413, 240]]), 'F'), (array([[441, 188],
#             [476, 188],
#             [476, 240],
#             [441, 240]]), 'O'), (array([[477, 188],
#             [507, 188],
#             [507, 238],
#             [477, 238]]), 'R')], [(array([[104, 275],
#             [136, 275],
#             [136, 323],
#             [104, 323]]), 'C'), (array([[136, 276],
#             [164, 276],
#             [164, 322],
#             [136, 322]]), 'L'), (array([[162, 276],
#             [194, 276],
#             [194, 323],
#             [162, 323]]), 'U'), (array([[197, 275],
#             [227, 275],
#             [227, 322],
#             [197, 322]]), 'B')], [(array([[252, 274],
#             [278, 274],
#             [278, 322],
#             [252, 322]]), 'S'), (array([[283, 274],
#             [308, 274],
#             [308, 320],
#             [283, 320]]), 'E'), (array([[310, 272],
#             [340, 272],
#             [340, 320],
#             [310, 320]]), 'C'), (array([[345, 273],
#             [373, 273],
#             [373, 319],
#             [345, 319]]), 'R'), (array([[378, 272],
#             [403, 272],
#             [403, 317],
#             [378, 317]]), 'E'), (array([[407, 271],
#             [432, 271],
#             [432, 316],
#             [407, 316]]), 'T'), (array([[426, 270],
#             [461, 270],
#             [461, 316],
#             [426, 316]]), 'A'), (array([[464, 269],
#             [494, 269],
#             [494, 314],
#             [464, 314]]), 'R'), (array([[497, 267],
#             [529, 267],
#             [529, 312],
#             [497, 312]]), 'Y')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/185.jpg',
#   [[(array([[ 54, 183],
#             [131, 183],
#             [131, 301],
#             [ 54, 301]]), 'E'), (array([[150, 182],
#             [218, 182],
#             [218, 304],
#             [150, 304]]), 'S'), (array([[239, 185],
#             [311, 185],
#             [311, 309],
#             [239, 309]]), 'S'), (array([[336, 188],
#             [417, 188],
#             [417, 315],
#             [336, 315]]), 'E'), (array([[433, 190],
#             [552, 190],
#             [552, 320],
#             [433, 320]]), 'X')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/316.jpg',
#   [[(array([[105, 158],
#             [340, 158],
#             [340, 319],
#             [105, 319]]), 'F'), (array([[174, 238],
#             [267, 238],
#             [267, 315],
#             [174, 315]]), 'o'), (array([[243, 231],
#             [319, 231],
#             [319, 310],
#             [243, 310]]), 'r'), (array([[298, 184],
#             [429, 184],
#             [429, 307],
#             [298, 307]]), 'd')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/103.jpg',
#   [[(array([[112, 115],
#             [134, 115],
#             [134, 143],
#             [112, 143]]), 'S'), (array([[135, 114],
#             [165, 114],
#             [165, 142],
#             [135, 142]]), 'T'), (array([[167, 114],
#             [183, 114],
#             [183, 141],
#             [167, 141]]), 'I'), (array([[186, 114],
#             [217, 114],
#             [217, 141],
#             [186, 141]]), 'R'), (array([[219, 113],
#             [246, 113],
#             [246, 141],
#             [219, 141]]), 'L'), (array([[248, 112],
#             [264, 112],
#             [264, 140],
#             [248, 140]]), 'I'), (array([[267, 112],
#             [302, 112],
#             [302, 140],
#             [267, 140]]), 'N'), (array([[300, 111],
#             [332, 111],
#             [332, 139],
#             [300, 139]]), 'G')], [(array([[350, 110],
#             [379, 110],
#             [379, 138],
#             [350, 138]]), 'C'), (array([[378, 109],
#             [412, 109],
#             [412, 138],
#             [378, 138]]), 'A'), (array([[413, 109],
#             [435, 109],
#             [435, 137],
#             [413, 137]]), 'S'), (array([[433, 108],
#             [464, 108],
#             [464, 136],
#             [433, 136]]), 'T'), (array([[466, 108],
#             [495, 108],
#             [495, 135],
#             [466, 135]]), 'L'), (array([[494, 107],
#             [524, 107],
#             [524, 135],
#             [494, 135]]), 'E')], [(array([[ 68, 283],
#             [103, 283],
#             [103, 315],
#             [ 68, 315]]), 'A'), (array([[107, 283],
#             [140, 283],
#             [140, 314],
#             [107, 314]]), 'R'), (array([[137, 283],
#             [170, 283],
#             [170, 315],
#             [137, 315]]), 'G'), (array([[170, 283],
#             [202, 283],
#             [202, 314],
#             [170, 314]]), 'Y'), (array([[204, 282],
#             [233, 282],
#             [233, 314],
#             [204, 314]]), 'L'), (array([[234, 282],
#             [263, 282],
#             [263, 313],
#             [234, 313]]), 'L'), (array([[265, 281],
#             [273, 281],
#             [273, 295],
#             [265, 295]]), "'"), (array([[277, 281],
#             [298, 281],
#             [298, 303],
#             [277, 303]]), 'S')], [(array([[318, 281],
#             [348, 281],
#             [348, 312],
#             [318, 312]]), 'L'), (array([[350, 279],
#             [385, 279],
#             [385, 312],
#             [350, 312]]), 'O'), (array([[383, 279],
#             [419, 279],
#             [419, 311],
#             [383, 311]]), 'D'), (array([[422, 278],
#             [456, 278],
#             [456, 310],
#             [422, 310]]), 'G'), (array([[455, 278],
#             [475, 278],
#             [475, 309],
#             [455, 309]]), 'I'), (array([[476, 277],
#             [514, 277],
#             [514, 309],
#             [476, 309]]), 'N'), (array([[513, 276],
#             [548, 276],
#             [548, 308],
#             [513, 308]]), 'G'), (array([[549, 275],
#             [573, 275],
#             [573, 308],
#             [549, 308]]), 'S')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/124.jpg',
#   [[(array([[138, 179],
#             [148, 179],
#             [148, 201],
#             [138, 201]]), 'I'), (array([[149, 179],
#             [170, 179],
#             [170, 200],
#             [149, 200]]), 'N'), (array([[172, 178],
#             [195, 178],
#             [195, 200],
#             [172, 200]]), 'V'), (array([[196, 177],
#             [212, 177],
#             [212, 199],
#             [196, 199]]), 'E'), (array([[215, 177],
#             [231, 177],
#             [231, 199],
#             [215, 199]]), 'S'), (array([[232, 176],
#             [249, 176],
#             [249, 198],
#             [232, 198]]), 'T'), (array([[250, 175],
#             [278, 175],
#             [278, 198],
#             [250, 198]]), 'M'), (array([[280, 175],
#             [295, 175],
#             [295, 197],
#             [280, 197]]), 'E'), (array([[298, 174],
#             [319, 174],
#             [319, 197],
#             [298, 197]]), 'N'), (array([[321, 174],
#             [338, 174],
#             [338, 196],
#             [321, 196]]), 'T'), (array([[339, 173],
#             [355, 173],
#             [355, 196],
#             [339, 196]]), 'S')], [(array([[136, 219],
#             [155, 219],
#             [155, 241],
#             [136, 241]]), 'P'), (array([[154, 218],
#             [171, 218],
#             [171, 241],
#             [154, 241]]), 'E'), (array([[173, 217],
#             [195, 217],
#             [195, 241],
#             [173, 241]]), 'N'), (array([[196, 217],
#             [212, 217],
#             [212, 240],
#             [196, 240]]), 'S'), (array([[214, 216],
#             [224, 216],
#             [224, 239],
#             [214, 239]]), 'I'), (array([[226, 216],
#             [245, 216],
#             [245, 239],
#             [226, 239]]), 'O'), (array([[246, 215],
#             [269, 215],
#             [269, 238],
#             [246, 238]]), 'N'), (array([[270, 215],
#             [286, 215],
#             [286, 238],
#             [270, 238]]), 'S')], [(array([[134, 259],
#             [162, 259],
#             [162, 282],
#             [134, 282]]), 'M'), (array([[164, 258],
#             [182, 258],
#             [182, 281],
#             [164, 281]]), 'O'), (array([[184, 258],
#             [204, 258],
#             [204, 281],
#             [184, 281]]), 'R'), (array([[205, 258],
#             [222, 258],
#             [222, 281],
#             [205, 281]]), 'T'), (array([[224, 256],
#             [245, 256],
#             [245, 280],
#             [224, 280]]), 'G'), (array([[244, 256],
#             [269, 256],
#             [269, 280],
#             [244, 280]]), 'A'), (array([[268, 256],
#             [290, 256],
#             [290, 280],
#             [268, 280]]), 'G'), (array([[291, 255],
#             [309, 255],
#             [309, 278],
#             [291, 278]]), 'E'), (array([[311, 254],
#             [328, 254],
#             [328, 279],
#             [311, 279]]), 'S')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/152.jpg',
#   [[(array([[822,  98],
#             [841,  98],
#             [841, 119],
#             [822, 119]]), 'e'), (array([[845,  97],
#             [863,  97],
#             [863, 119],
#             [845, 119]]), 's'), (array([[867,  97],
#             [884,  97],
#             [884, 119],
#             [867, 119]]), 's'), (array([[888,  97],
#             [907,  97],
#             [907, 119],
#             [888, 119]]), 'e'), (array([[911,  97],
#             [939,  97],
#             [939, 118],
#             [911, 118]]), 'n'), (array([[943,  96],
#             [962,  96],
#             [962, 118],
#             [943, 118]]), 'c'), (array([[966,  96],
#             [984,  96],
#             [984, 118],
#             [966, 118]]), 'e')], [(array([[1006,   96],
#             [1029,   96],
#             [1029,  118],
#             [1006,  118]]), 'o'), (array([[1028,   44],
#             [1061,   44],
#             [1061,  131],
#             [1028,  131]]), 'f')], [(array([[956, 171],
#             [974, 171],
#             [974, 196],
#             [956, 196]]), 'c'), (array([[ 984,  171],
#             [1008,  171],
#             [1008,  196],
#             [ 984,  196]]), 'o'), (array([[1019,  170],
#             [1054,  170],
#             [1054,  195],
#             [1019,  195]]), 'm'), (array([[1067,  170],
#             [1090,  170],
#             [1090,  204],
#             [1067,  204]]), 'p'), (array([[1102,  171],
#             [1122,  171],
#             [1122,  195],
#             [1102,  195]]), 'u'), (array([[1134,  164],
#             [1150,  164],
#             [1150,  194],
#             [1134,  194]]), 't'), (array([[1161,  161],
#             [1167,  161],
#             [1167,  194],
#             [1161,  194]]), 'i'), (array([[1180,  170],
#             [1201,  170],
#             [1201,  194],
#             [1180,  194]]), 'n'), (array([[1213,  170],
#             [1236,  170],
#             [1236,  203],
#             [1213,  203]]), 'g')], [(array([[379, 364],
#             [409, 364],
#             [409, 403],
#             [379, 403]]), 'T'), (array([[425, 363],
#             [456, 363],
#             [456, 403],
#             [425, 403]]), 'H'), (array([[475, 363],
#             [499, 363],
#             [499, 402],
#             [475, 402]]), 'E')], [(array([[544, 362],
#             [567, 362],
#             [567, 401],
#             [544, 401]]), 'E'), (array([[584, 361],
#             [609, 361],
#             [609, 401],
#             [584, 401]]), 'S'), (array([[626, 360],
#             [651, 360],
#             [651, 400],
#             [626, 400]]), 'S'), (array([[668, 360],
#             [692, 360],
#             [692, 400],
#             [668, 400]]), 'E'), (array([[709, 360],
#             [742, 360],
#             [742, 399],
#             [709, 399]]), 'N'), (array([[759, 359],
#             [789, 359],
#             [789, 399],
#             [759, 399]]), 'C'), (array([[806, 359],
#             [828, 359],
#             [828, 398],
#             [806, 398]]), 'E')], [(array([[872, 358],
#             [911, 358],
#             [911, 398],
#             [872, 398]]), 'O'), (array([[928, 358],
#             [949, 358],
#             [949, 397],
#             [928, 397]]), 'F')], [(array([[642, 477],
#             [707, 477],
#             [707, 538],
#             [642, 538]]), 'A'), (array([[722, 492],
#             [770, 492],
#             [770, 537],
#             [722, 537]]), 'R'), (array([[782, 490],
#             [825, 490],
#             [825, 536],
#             [782, 536]]), 'T'), (array([[841, 491],
#             [862, 491],
#             [862, 535],
#             [841, 535]]), 'I'), (array([[881, 490],
#             [914, 490],
#             [914, 535],
#             [881, 535]]), 'F'), (array([[930, 490],
#             [952, 490],
#             [952, 534],
#             [930, 534]]), 'I'), (array([[ 970,  488],
#             [1012,  488],
#             [1012,  535],
#             [ 970,  535]]), 'C'), (array([[1029,  489],
#             [1051,  489],
#             [1051,  533],
#             [1029,  533]]), 'I'), (array([[1068,  487],
#             [1115,  487],
#             [1115,  533],
#             [1068,  533]]), 'A'), (array([[1131,  488],
#             [1167,  488],
#             [1167,  532],
#             [1131,  532]]), 'L')], [(array([[596, 598],
#             [617, 598],
#             [617, 642],
#             [596, 642]]), 'I'), (array([[634, 596],
#             [682, 596],
#             [682, 641],
#             [634, 641]]), 'N'), (array([[696, 595],
#             [738, 595],
#             [738, 640],
#             [696, 640]]), 'T'), (array([[753, 595],
#             [788, 595],
#             [788, 640],
#             [753, 640]]), 'E'), (array([[804, 594],
#             [840, 594],
#             [840, 639],
#             [804, 639]]), 'L'), (array([[855, 594],
#             [891, 594],
#             [891, 639],
#             [855, 639]]), 'L'), (array([[906, 593],
#             [929, 593],
#             [929, 638],
#             [906, 638]]), 'I'), (array([[947, 591],
#             [993, 591],
#             [993, 638],
#             [947, 638]]), 'G'), (array([[1009,  592],
#             [1044,  592],
#             [1044,  637],
#             [1009,  637]]), 'E'), (array([[1058,  591],
#             [1107,  591],
#             [1107,  636],
#             [1058,  636]]), 'N'), (array([[1122,  589],
#             [1164,  589],
#             [1164,  636],
#             [1122,  636]]), 'C'), (array([[1180,  590],
#             [1215,  590],
#             [1215,  634],
#             [1180,  634]]), 'E')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/114.jpg',
#   [[(array([[633, 444],
#             [708, 444],
#             [708, 487],
#             [633, 487]]), 'R'), (array([[686, 442],
#             [738, 442],
#             [738, 485],
#             [686, 485]]), 'Y'), (array([[735, 441],
#             [784, 441],
#             [784, 484],
#             [735, 484]]), 'A'), (array([[781, 440],
#             [831, 440],
#             [831, 483],
#             [781, 483]]), 'N'), (array([[832, 440],
#             [877, 440],
#             [877, 481],
#             [832, 481]]), 'A'), (array([[871, 439],
#             [892, 439],
#             [892, 479],
#             [871, 479]]), 'I'), (array([[890, 438],
#             [946, 438],
#             [946, 478],
#             [890, 478]]), 'R')], [(array([[277, 723],
#             [284, 723],
#             [284, 733],
#             [277, 733]]), '')], [(array([[  7, 606],
#             [ 28, 606],
#             [ 28, 628],
#             [  7, 628]]), '')], [(array([[287, 724],
#             [294, 724],
#             [294, 734],
#             [287, 734]]), '')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/231.jpg',
#   [[(array([[ 68, 237],
#             [126, 237],
#             [126, 310],
#             [ 68, 310]]), 'L'), (array([[138, 236],
#             [218, 236],
#             [218, 311],
#             [138, 311]]), 'O'), (array([[228, 235],
#             [313, 235],
#             [313, 310],
#             [228, 310]]), 'U'), (array([[330, 237],
#             [409, 237],
#             [409, 311],
#             [330, 311]]), 'N'), (array([[417, 236],
#             [493, 236],
#             [493, 312],
#             [417, 312]]), 'G'), (array([[505, 236],
#             [565, 236],
#             [565, 310],
#             [505, 310]]), 'E')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/120.jpg',
#   [[(array([[ 55, 110],
#             [103, 110],
#             [103, 174],
#             [ 55, 174]]), 'U'), (array([[107, 108],
#             [155, 108],
#             [155, 175],
#             [107, 175]]), 'S'), (array([[159, 109],
#             [197, 109],
#             [197, 174],
#             [159, 174]]), 'E')], [(array([[223, 107],
#             [279, 107],
#             [279, 173],
#             [223, 173]]), 'O'), (array([[285, 107],
#             [334, 107],
#             [334, 172],
#             [285, 172]]), 'N'), (array([[341, 107],
#             [376, 107],
#             [376, 172],
#             [341, 172]]), 'L'), (array([[381, 106],
#             [433, 106],
#             [433, 172],
#             [381, 172]]), 'Y')], [(array([[457, 107],
#             [510, 107],
#             [510, 171],
#             [457, 171]]), 'D'), (array([[516, 107],
#             [562, 107],
#             [562, 171],
#             [516, 171]]), 'R'), (array([[571, 105],
#             [585, 105],
#             [585, 171],
#             [571, 171]]), 'I'), (array([[600, 129],
#             [628, 129],
#             [628, 142],
#             [600, 142]]), '-'), (array([[640, 106],
#             [721, 106],
#             [721, 171],
#             [640, 171]]), 'W'), (array([[728, 107],
#             [742, 107],
#             [742, 172],
#             [728, 172]]), 'I'), (array([[751, 108],
#             [796, 108],
#             [796, 169],
#             [751, 169]]), 'P'), (array([[803, 109],
#             [842, 109],
#             [842, 174],
#             [803, 174]]), 'E')], [(array([[871, 109],
#             [930, 109],
#             [930, 175],
#             [871, 175]]), 'M'), (array([[936, 110],
#             [991, 110],
#             [991, 176],
#             [936, 176]]), 'A'), (array([[ 998,  112],
#             [1043,  112],
#             [1043,  175],
#             [ 998,  175]]), 'R'), (array([[1050,  112],
#             [1097,  112],
#             [1097,  177],
#             [1050,  177]]), 'K'), (array([[1105,  114],
#             [1143,  114],
#             [1143,  177],
#             [1105,  177]]), 'E'), (array([[1151,  114],
#             [1195,  114],
#             [1195,  178],
#             [1151,  178]]), 'R'), (array([[1202,  115],
#             [1247,  115],
#             [1247,  180],
#             [1202,  180]]), 'S')], [(array([[ 59, 240],
#             [112, 240],
#             [112, 305],
#             [ 59, 305]]), 'O'), (array([[117, 241],
#             [165, 241],
#             [165, 304],
#             [117, 304]]), 'N')], [(array([[194, 242],
#             [241, 242],
#             [241, 305],
#             [194, 305]]), 'T'), (array([[248, 242],
#             [297, 242],
#             [297, 306],
#             [248, 306]]), 'H'), (array([[306, 242],
#             [344, 242],
#             [344, 305],
#             [306, 305]]), 'E'), (array([[349, 240],
#             [397, 240],
#             [397, 308],
#             [349, 308]]), 'S'), (array([[404, 243],
#             [443, 243],
#             [443, 305],
#             [404, 305]]), 'E')], [(array([[473, 243],
#             [519, 243],
#             [519, 306],
#             [473, 306]]), 'B'), (array([[523, 241],
#             [581, 241],
#             [581, 308],
#             [523, 308]]), 'O'), (array([[588, 243],
#             [641, 243],
#             [641, 307],
#             [588, 307]]), 'A'), (array([[650, 244],
#             [695, 244],
#             [695, 307],
#             [650, 307]]), 'R'), (array([[704, 245],
#             [757, 245],
#             [757, 307],
#             [704, 307]]), 'D'), (array([[764, 244],
#             [809, 244],
#             [809, 311],
#             [764, 311]]), 'S')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/186.jpg',
#   [[(array([[ 25, 223],
#             [ 69, 223],
#             [ 69, 292],
#             [ 25, 292]]), 'F'), (array([[ 74, 224],
#             [125, 224],
#             [125, 295],
#             [ 74, 295]]), 'R'), (array([[132, 226],
#             [175, 226],
#             [175, 295],
#             [132, 295]]), 'E'), (array([[184, 228],
#             [227, 228],
#             [227, 297],
#             [184, 297]]), 'E')], [(array([[267, 231],
#             [314, 231],
#             [314, 299],
#             [267, 299]]), 'D'), (array([[321, 233],
#             [363, 233],
#             [363, 300],
#             [321, 300]]), 'E'), (array([[369, 234],
#             [409, 234],
#             [409, 301],
#             [369, 301]]), 'L'), (array([[412, 235],
#             [429, 235],
#             [429, 301],
#             [412, 301]]), 'I'), (array([[431, 236],
#             [473, 236],
#             [473, 302],
#             [431, 302]]), 'V'), (array([[481, 237],
#             [525, 237],
#             [525, 303],
#             [481, 303]]), 'E'), (array([[527, 239],
#             [575, 239],
#             [575, 303],
#             [527, 303]]), 'R'), (array([[292, 232],
#             [610, 232],
#             [610, 304],
#             [292, 304]]), 'Y')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/310.jpg',
#   [[(array([[ 67, 272],
#             [107, 272],
#             [107, 303],
#             [ 67, 303]]), 'O'), (array([[111, 281],
#             [140, 281],
#             [140, 304],
#             [111, 304]]), 's'), (array([[144, 273],
#             [174, 273],
#             [174, 304],
#             [144, 304]]), 'b'), (array([[178, 282],
#             [207, 282],
#             [207, 305],
#             [178, 305]]), 'o'), (array([[212, 282],
#             [236, 282],
#             [236, 304],
#             [212, 304]]), 'r'), (array([[239, 282],
#             [267, 282],
#             [267, 304],
#             [239, 304]]), 'n'), (array([[272, 283],
#             [300, 283],
#             [300, 305],
#             [272, 305]]), 'e')], [(array([[327, 274],
#             [367, 274],
#             [367, 306],
#             [327, 306]]), 'G'), (array([[372, 283],
#             [401, 283],
#             [401, 306],
#             [372, 306]]), 'a'), (array([[406, 284],
#             [430, 284],
#             [430, 306],
#             [406, 306]]), 'r'), (array([[433, 284],
#             [462, 284],
#             [462, 307],
#             [433, 307]]), 'a'), (array([[467, 284],
#             [498, 284],
#             [498, 316],
#             [467, 316]]), 'g'), (array([[502, 284],
#             [531, 284],
#             [531, 307],
#             [502, 307]]), 'e'), (array([[536, 284],
#             [565, 284],
#             [565, 307],
#             [536, 307]]), 's')], [(array([[441, 474],
#             [525, 474],
#             [525, 479],
#             [441, 479]]), '')], [(array([[398, 367],
#             [461, 367],
#             [461, 375],
#             [398, 375]]), '')], [(array([[546, 426],
#             [639, 426],
#             [639, 439],
#             [546, 439]]), '')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/255.jpg',
#   [[(array([[ 82, 350],
#             [140, 350],
#             [140, 408],
#             [ 82, 408]]), 'A'), (array([[157, 347],
#             [207, 347],
#             [207, 405],
#             [157, 405]]), 'C'), (array([[228, 345],
#             [277, 345],
#             [277, 403],
#             [228, 403]]), 'C'), (array([[303, 345],
#             [342, 345],
#             [342, 400],
#             [303, 400]]), 'E'), (array([[368, 341],
#             [417, 341],
#             [417, 399],
#             [368, 399]]), 'S'), (array([[439, 338],
#             [487, 338],
#             [487, 396],
#             [439, 396]]), 'S')], [(array([[547, 337],
#             [592, 337],
#             [592, 391],
#             [547, 391]]), 'T'), (array([[609, 335],
#             [661, 335],
#             [661, 389],
#             [609, 389]]), 'O')], [(array([[721, 331],
#             [767, 331],
#             [767, 384],
#             [721, 384]]), 'K'), (array([[786, 329],
#             [829, 329],
#             [829, 381],
#             [786, 381]]), 'N'), (array([[850, 327],
#             [897, 327],
#             [897, 378],
#             [850, 378]]), 'O'), (array([[916, 324],
#             [977, 324],
#             [977, 375],
#             [916, 375]]), 'W')], [(array([[  0, 752],
#             [111, 752],
#             [111, 852],
#             [  0, 852]]), 'B'), (array([[103, 747],
#             [221, 747],
#             [221, 852],
#             [103, 852]]), 'A'), (array([[221, 740],
#             [336, 740],
#             [336, 847],
#             [221, 847]]), 'G'), (array([[336, 737],
#             [450, 737],
#             [450, 840],
#             [336, 840]]), 'G'), (array([[430, 734],
#             [539, 734],
#             [539, 836],
#             [430, 836]]), 'A'), (array([[542, 727],
#             [652, 727],
#             [652, 828],
#             [542, 828]]), 'G'), (array([[638, 720],
#             [734, 720],
#             [734, 823],
#             [638, 823]]), 'E')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/160.jpg',
#   [[(array([[  6,  61],
#             [ 37,  61],
#             [ 37, 100],
#             [  6, 100]]), 'E'), (array([[ 43,  60],
#             [ 72,  60],
#             [ 72, 101],
#             [ 43, 101]]), 'S'), (array([[ 76,  61],
#             [109,  61],
#             [109, 101],
#             [ 76, 101]]), 'P'), (array([[106,  61],
#             [150,  61],
#             [150, 101],
#             [106, 101]]), 'A'), (array([[153,  61],
#             [198,  61],
#             [198, 102],
#             [153, 102]]), 'N'), (array([[202,  61],
#             [246,  61],
#             [246, 103],
#             [202, 103]]), 'O'), (array([[251,  62],
#             [283,  62],
#             [283, 103],
#             [251, 103]]), 'L'), (array([[285,  84],
#             [304,  84],
#             [304,  91],
#             [285,  91]]), '-'), (array([[306,  63],
#             [325,  63],
#             [325, 103],
#             [306, 103]]), 'I'), (array([[329,  63],
#             [374,  63],
#             [374, 104],
#             [329, 104]]), 'N'), (array([[377,  63],
#             [421,  63],
#             [421, 104],
#             [377, 104]]), 'G'), (array([[426,  64],
#             [458,  64],
#             [458, 104],
#             [426, 104]]), 'L'), (array([[461,  64],
#             [493,  64],
#             [493, 104],
#             [461, 104]]), 'E'), (array([[498,  64],
#             [527,  64],
#             [527, 105],
#             [498, 105]]), 'S')], [(array([[  2, 118],
#             [ 24, 118],
#             [ 24, 158],
#             [  2, 158]]), 'I'), (array([[ 25, 119],
#             [ 72, 119],
#             [ 72, 159],
#             [ 25, 159]]), 'N'), (array([[ 75, 119],
#             [118, 119],
#             [118, 161],
#             [ 75, 161]]), 'G'), (array([[124, 120],
#             [155, 120],
#             [155, 160],
#             [124, 160]]), 'L'), (array([[160, 120],
#             [191, 120],
#             [191, 161],
#             [160, 161]]), 'E'), (array([[196, 119],
#             [227, 119],
#             [227, 162],
#             [196, 162]]), 'S'), (array([[230, 143],
#             [249, 143],
#             [249, 149],
#             [230, 149]]), '-'), (array([[251, 121],
#             [284, 121],
#             [284, 161],
#             [251, 161]]), 'E'), (array([[288, 120],
#             [319, 120],
#             [319, 163],
#             [288, 163]]), 'S'), (array([[323, 122],
#             [357, 122],
#             [357, 162],
#             [323, 162]]), 'P'), (array([[354, 122],
#             [398, 122],
#             [398, 162],
#             [354, 162]]), 'A'), (array([[400, 122],
#             [445, 122],
#             [445, 163],
#             [400, 163]]), 'N'), (array([[450, 122],
#             [494, 122],
#             [494, 163],
#             [450, 163]]), 'O'), (array([[497, 123],
#             [530, 123],
#             [530, 162],
#             [497, 162]]), 'L')], [(array([[ 14, 181],
#             [ 72, 181],
#             [ 72, 235],
#             [ 14, 235]]), '')], [(array([[ 63, 178],
#             [118, 178],
#             [118, 233],
#             [ 63, 233]]), '')], [(array([[ 97, 176],
#             [161, 176],
#             [161, 236],
#             [ 97, 236]]), '')], [(array([[154, 179],
#             [197, 179],
#             [197, 225],
#             [154, 225]]), '')], [(array([[202, 182],
#             [265, 182],
#             [265, 237],
#             [202, 237]]), '')], [(array([[277, 184],
#             [327, 184],
#             [327, 233],
#             [277, 233]]), '')], [(array([[319, 185],
#             [393, 185],
#             [393, 232],
#             [319, 232]]), '')], [(array([[163,  50],
#             [187,  50],
#             [187,  60],
#             [163,  60]]), '')], [(array([[469,  50],
#             [487,  50],
#             [487,  63],
#             [469,  63]]), '')], [(array([[410, 111],
#             [434, 111],
#             [434, 120],
#             [410, 120]]), '')], [(array([[170, 106],
#             [186, 106],
#             [186, 119],
#             [170, 119]]), '')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/259.jpg',
#   [[(array([[ 28, 102],
#             [201, 102],
#             [201, 372],
#             [ 28, 372]]), 'S'), (array([[228,  99],
#             [309,  99],
#             [309, 367],
#             [228, 367]]), 'T'), (array([[341,  98],
#             [495,  98],
#             [495, 369],
#             [341, 369]]), 'O'), (array([[478, 101],
#             [600, 101],
#             [600, 357],
#             [478, 357]]), 'P')], [(array([[196,   0],
#             [457,   0],
#             [457,  30],
#             [196,  30]]), '')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/314.jpg',
#   [[(array([[ 38, 159],
#             [199, 159],
#             [199, 371],
#             [ 38, 371]]), 'F'), (array([[201, 158],
#             [382, 158],
#             [382, 362],
#             [201, 362]]), 'A'), (array([[412, 155],
#             [584, 155],
#             [584, 350],
#             [412, 350]]), 'X')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/180.jpg',
#   [[(array([[140,  90],
#             [184,  90],
#             [184, 176],
#             [140, 176]]), 'P'), (array([[190,  96],
#             [224,  96],
#             [224, 177],
#             [190, 177]]), 'L'), (array([[231,  94],
#             [269,  94],
#             [269, 175],
#             [231, 175]]), 'E'), (array([[273,  95],
#             [323,  95],
#             [323, 177],
#             [273, 177]]), 'A'), (array([[330,  98],
#             [369,  98],
#             [369, 175],
#             [330, 175]]), 'S'), (array([[375,  97],
#             [413,  97],
#             [413, 179],
#             [375, 179]]), 'E')], [(array([[135, 195],
#             [183, 195],
#             [183, 277],
#             [135, 277]]), 'D'), (array([[188, 195],
#             [232, 195],
#             [232, 276],
#             [188, 276]]), 'O')], [(array([[262, 203],
#             [316, 203],
#             [316, 281],
#             [262, 281]]), 'N'), (array([[322, 198],
#             [365, 198],
#             [365, 279],
#             [322, 279]]), 'O'), (array([[372, 206],
#             [414, 206],
#             [414, 282],
#             [372, 282]]), 'T')], [(array([[112, 294],
#             [160, 294],
#             [160, 377],
#             [112, 377]]), 'D'), (array([[165, 299],
#             [187, 299],
#             [187, 380],
#             [165, 380]]), 'I'), (array([[193, 301],
#             [232, 301],
#             [232, 377],
#             [193, 377]]), 'S'), (array([[238, 304],
#             [279, 304],
#             [279, 381],
#             [238, 381]]), 'T'), (array([[286, 305],
#             [329, 305],
#             [329, 381],
#             [286, 381]]), 'U'), (array([[335, 307],
#             [378, 307],
#             [378, 382],
#             [335, 382]]), 'R'), (array([[386, 305],
#             [432, 305],
#             [432, 386],
#             [386, 386]]), 'B')], [(array([[187, 449],
#             [188, 449],
#             [188, 451],
#             [187, 451]]), '.'), (array([[192, 449],
#             [193, 449],
#             [193, 451],
#             [192, 451]]), '.'), (array([[198, 449],
#             [199, 449],
#             [199, 451],
#             [198, 451]]), '.'), (array([[203, 437],
#             [205, 437],
#             [205, 452],
#             [203, 452]]), 'I'), (array([[209, 437],
#             [220, 437],
#             [220, 452],
#             [209, 452]]), 'M')], [(array([[229, 437],
#             [237, 437],
#             [237, 452],
#             [229, 452]]), 'R'), (array([[241, 439],
#             [246, 439],
#             [246, 453],
#             [241, 453]]), 'E'), (array([[249, 438],
#             [256, 438],
#             [256, 453],
#             [249, 453]]), 'C'), (array([[260, 437],
#             [268, 437],
#             [268, 453],
#             [260, 453]]), 'O'), (array([[271, 439],
#             [280, 439],
#             [280, 454],
#             [271, 454]]), 'V'), (array([[284, 440],
#             [290, 440],
#             [290, 454],
#             [284, 454]]), 'E'), (array([[293, 439],
#             [300, 439],
#             [300, 454],
#             [293, 454]]), 'R'), (array([[304, 440],
#             [306, 440],
#             [306, 455],
#             [304, 455]]), 'I'), (array([[311, 440],
#             [319, 440],
#             [319, 455],
#             [311, 455]]), 'N'), (array([[323, 439],
#             [332, 439],
#             [332, 455],
#             [323, 455]]), 'G'), (array([[335, 440],
#             [337, 440],
#             [337, 455],
#             [335, 455]]), '!'), (array([[341, 440],
#             [343, 440],
#             [343, 455],
#             [341, 455]]), '!')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/168.jpg',
#   [[(array([[230, 204],
#             [253, 204],
#             [253, 235],
#             [230, 235]]), 'E'), (array([[257, 203],
#             [266, 203],
#             [266, 235],
#             [257, 235]]), 'l'), (array([[270, 215],
#             [292, 215],
#             [292, 236],
#             [270, 236]]), 'e'), (array([[295, 215],
#             [315, 215],
#             [315, 237],
#             [295, 237]]), 'c'), (array([[318, 210],
#             [334, 210],
#             [334, 237],
#             [318, 237]]), 't'), (array([[337, 216],
#             [354, 216],
#             [354, 236],
#             [337, 236]]), 'r'), (array([[354, 216],
#             [379, 216],
#             [379, 237],
#             [354, 237]]), 'o'), (array([[382, 205],
#             [392, 205],
#             [392, 236],
#             [382, 236]]), 'l'), (array([[395, 217],
#             [419, 217],
#             [419, 237],
#             [395, 237]]), 'u'), (array([[420, 217],
#             [447, 217],
#             [447, 237],
#             [420, 237]]), 'x')]],
#   1),
# ...
#   [[(array([[340, 929],
#             [378, 929],
#             [378, 991],
#             [340, 991]]), 'P'), (array([[378, 928],
#             [414, 928],
#             [414, 992],
#             [378, 992]]), 'O'), (array([[414, 928],
#             [450, 928],
#             [450, 992],
#             [414, 992]]), 'C'), (array([[449, 929],
#             [490, 929],
#             [490, 991],
#             [449, 991]]), 'K'), (array([[487, 929],
#             [522, 929],
#             [522, 991],
#             [487, 991]]), 'E'), (array([[526, 929],
#             [557, 929],
#             [557, 990],
#             [526, 990]]), 'T')], [(array([[570, 928],
#             [606, 928],
#             [606, 990],
#             [570, 990]]), 'F'), (array([[603, 929],
#             [630, 929],
#             [630, 990],
#             [603, 990]]), 'L'), (array([[631, 929],
#             [665, 929],
#             [665, 990],
#             [631, 990]]), 'A'), (array([[670, 927],
#             [705, 927],
#             [705, 991],
#             [670, 991]]), 'S'), (array([[703, 928],
#             [744, 928],
#             [744, 990],
#             [703, 990]]), 'H')], [(array([[747, 875],
#             [786, 875],
#             [786, 914],
#             [747, 914]]), 'U'), (array([[773, 859],
#             [804, 859],
#             [804, 896],
#             [773, 896]]), 'P'), (array([[801, 836],
#             [837, 836],
#             [837, 874],
#             [801, 874]]), 'G'), (array([[828, 821],
#             [870, 821],
#             [870, 859],
#             [828, 859]]), 'R'), (array([[870, 807],
#             [898, 807],
#             [898, 844],
#             [870, 844]]), 'A'), (array([[889, 792],
#             [925, 792],
#             [925, 830],
#             [889, 830]]), 'D'), (array([[921, 778],
#             [956, 778],
#             [956, 817],
#             [921, 817]]), 'E')], [(array([[ 971,  761],
#             [1001,  761],
#             [1001,  799],
#             [ 971,  799]]), 'Y'), (array([[1006,  756],
#             [1038,  756],
#             [1038,  791],
#             [1006,  791]]), 'O'), (array([[1038,  747],
#             [1069,  747],
#             [1069,  784],
#             [1038,  784]]), 'U'), (array([[1072,  743],
#             [1106,  743],
#             [1106,  779],
#             [1072,  779]]), 'R')], [(array([[1129,  737],
#             [1160,  737],
#             [1160,  772],
#             [1129,  772]]), 'D'), (array([[1163,  735],
#             [1178,  735],
#             [1178,  769],
#             [1163,  769]]), 'I'), (array([[1182,  733],
#             [1213,  733],
#             [1213,  768],
#             [1182,  768]]), 'G'), (array([[1217,  733],
#             [1231,  733],
#             [1231,  767],
#             [1217,  767]]), 'I'), (array([[1235,  734],
#             [1261,  734],
#             [1261,  766],
#             [1235,  766]]), 'T'), (array([[1260,  734],
#             [1288,  734],
#             [1288,  767],
#             [1260,  767]]), 'A'), (array([[1292,  735],
#             [1319,  735],
#             [1319,  769],
#             [1292,  769]]), 'L')], [(array([[1344,  737],
#             [1371,  737],
#             [1371,  773],
#             [1344,  773]]), 'L'), (array([[1373,  740],
#             [1390,  740],
#             [1390,  775],
#             [1373,  775]]), 'I'), (array([[1390,  742],
#             [1417,  742],
#             [1417,  777],
#             [1390,  777]]), 'F'), (array([[1416,  746],
#             [1445,  746],
#             [1445,  783],
#             [1416,  783]]), 'E'), (array([[1447,  750],
#             [1459,  750],
#             [1459,  786],
#             [1447,  786]]), '!')], [(array([[1091,  289],
#             [1137,  289],
#             [1137,  354],
#             [1091,  354]]), 'S'), (array([[1145,  290],
#             [1194,  290],
#             [1194,  353],
#             [1145,  353]]), 'A'), (array([[1203,  291],
#             [1269,  291],
#             [1269,  353],
#             [1203,  353]]), 'M'), (array([[1283,  290],
#             [1328,  290],
#             [1328,  354],
#             [1283,  354]]), 'S'), (array([[1338,  291],
#             [1382,  291],
#             [1382,  355],
#             [1338,  355]]), 'U'), (array([[1393,  291],
#             [1441,  291],
#             [1441,  354],
#             [1393,  354]]), 'N'), (array([[1454,  290],
#             [1497,  290],
#             [1497,  355],
#             [1454,  355]]), 'G')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/253.jpg',
#   [[(array([[ 40, 205],
#             [126, 205],
#             [126, 308],
#             [ 40, 308]]), 'V'), (array([[147, 205],
#             [196, 205],
#             [196, 307],
#             [147, 307]]), 'I'), (array([[219, 203],
#             [311, 203],
#             [311, 307],
#             [219, 307]]), 'N'), (array([[330, 206],
#             [413, 206],
#             [413, 305],
#             [330, 305]]), 'C'), (array([[436, 200],
#             [516, 200],
#             [516, 303],
#             [436, 303]]), 'E'), (array([[537, 199],
#             [619, 199],
#             [619, 300],
#             [537, 300]]), 'S')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/290.jpg',
#   [[(array([[274, 345],
#             [301, 345],
#             [301, 368],
#             [274, 368]]), 'M'), (array([[299, 345],
#             [309, 345],
#             [309, 367],
#             [299, 367]]), 'i'), (array([[307, 350],
#             [324, 350],
#             [324, 367],
#             [307, 367]]), 'c'), (array([[324, 350],
#             [336, 350],
#             [336, 366],
#             [324, 366]]), 'r'), (array([[334, 349],
#             [352, 349],
#             [352, 366],
#             [334, 366]]), 'o'), (array([[351, 349],
#             [368, 349],
#             [368, 366],
#             [351, 366]]), 's'), (array([[369, 349],
#             [386, 349],
#             [386, 366],
#             [369, 366]]), 'o'), (array([[386, 344],
#             [397, 344],
#             [397, 366],
#             [386, 366]]), 'f'), (array([[396, 346],
#             [405, 346],
#             [405, 366],
#             [396, 366]]), 't')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/150.jpg',
#   [[(array([[ 79, 187],
#             [232, 187],
#             [232, 342],
#             [ 79, 342]]), 'B'), (array([[248, 182],
#             [385, 182],
#             [385, 340],
#             [248, 340]]), 'A'), (array([[415, 184],
#             [567, 184],
#             [567, 338],
#             [415, 338]]), 'R')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/304.jpg',
#   [[(array([[ 81, 171],
#             [135, 171],
#             [135, 231],
#             [ 81, 231]]), 'B'), (array([[142, 185],
#             [194, 185],
#             [194, 234],
#             [142, 234]]), 'e'), (array([[200, 186],
#             [252, 186],
#             [252, 235],
#             [200, 235]]), 'a'), (array([[262, 187],
#             [295, 187],
#             [295, 234],
#             [262, 234]]), 'r'), (array([[300, 173],
#             [352, 173],
#             [352, 236],
#             [300, 236]]), 'd'), (array([[358, 189],
#             [437, 189],
#             [437, 236],
#             [358, 236]]), 'w'), (array([[442, 189],
#             [494, 189],
#             [494, 238],
#             [442, 238]]), 'e'), (array([[503, 175],
#             [521, 175],
#             [521, 237],
#             [503, 237]]), 'l'), (array([[533, 176],
#             [551, 176],
#             [551, 238],
#             [533, 238]]), 'l')], [(array([[ 79, 251],
#             [110, 251],
#             [110, 286],
#             [ 79, 286]]), 'C'), (array([[114, 261],
#             [139, 261],
#             [139, 287],
#             [114, 287]]), 'o'), (array([[145, 261],
#             [166, 261],
#             [166, 286],
#             [145, 286]]), 'n'), (array([[172, 261],
#             [194, 261],
#             [194, 288],
#             [172, 288]]), 's'), (array([[197, 254],
#             [210, 254],
#             [210, 287],
#             [197, 287]]), 't'), (array([[214, 263],
#             [228, 263],
#             [228, 287],
#             [214, 287]]), 'r'), (array([[232, 263],
#             [254, 263],
#             [254, 289],
#             [232, 289]]), 'u'), (array([[259, 263],
#             [283, 263],
#             [283, 289],
#             [259, 289]]), 'c'), (array([[285, 256],
#             [298, 256],
#             [298, 289],
#             [285, 289]]), 't'), (array([[303, 255],
#             [307, 255],
#             [307, 289],
#             [303, 289]]), 'i'), (array([[313, 264],
#             [338, 264],
#             [338, 290],
#             [313, 290]]), 'o'), (array([[344, 265],
#             [366, 265],
#             [366, 290],
#             [344, 290]]), 'n')], [(array([[389, 256],
#             [412, 256],
#             [412, 291],
#             [389, 291]]), 'L'), (array([[418, 256],
#             [423, 256],
#             [423, 291],
#             [418, 291]]), 'i'), (array([[430, 266],
#             [468, 266],
#             [468, 292],
#             [430, 292]]), 'm'), (array([[475, 257],
#             [479, 257],
#             [479, 292],
#             [475, 292]]), 'i'), (array([[484, 258],
#             [497, 258],
#             [497, 292],
#             [484, 292]]), 't'), (array([[500, 267],
#             [525, 267],
#             [525, 293],
#             [500, 293]]), 'e'), (array([[529, 258],
#             [553, 258],
#             [553, 293],
#             [529, 293]]), 'd')], [(array([[ 23, 356],
#             [ 36, 356],
#             [ 36, 371],
#             [ 23, 371]]), 'c'), (array([[ 38, 356],
#             [ 52, 356],
#             [ 52, 371],
#             [ 38, 371]]), 'o'), (array([[ 54, 357],
#             [ 68, 357],
#             [ 68, 372],
#             [ 54, 372]]), 'n'), (array([[ 70, 357],
#             [ 82, 357],
#             [ 82, 373],
#             [ 70, 373]]), 's'), (array([[ 84, 354],
#             [ 92, 354],
#             [ 92, 373],
#             [ 84, 373]]), 't'), (array([[ 92, 358],
#             [102, 358],
#             [102, 373],
#             [ 92, 373]]), 'r'), (array([[103, 359],
#             [117, 359],
#             [117, 373],
#             [103, 373]]), 'u'), (array([[119, 359],
#             [133, 359],
#             [133, 374],
#             [119, 374]]), 'c'), (array([[135, 355],
#             [142, 355],
#             [142, 374],
#             [135, 374]]), 't'), (array([[143, 355],
#             [150, 355],
#             [150, 374],
#             [143, 374]]), 'i'), (array([[151, 360],
#             [165, 360],
#             [165, 375],
#             [151, 375]]), 'o'), (array([[167, 360],
#             [182, 360],
#             [182, 375],
#             [167, 375]]), 'n')], [(array([[216, 362],
#             [226, 362],
#             [226, 376],
#             [216, 376]]), 'r'), (array([[227, 362],
#             [240, 362],
#             [240, 377],
#             [227, 377]]), 'e'), (array([[243, 357],
#             [252, 357],
#             [252, 377],
#             [243, 377]]), 'f'), (array([[252, 363],
#             [267, 363],
#             [267, 378],
#             [252, 378]]), 'u'), (array([[268, 363],
#             [279, 363],
#             [279, 378],
#             [268, 378]]), 'r'), (array([[279, 358],
#             [294, 358],
#             [294, 378],
#             [279, 378]]), 'b'), (array([[296, 358],
#             [303, 358],
#             [303, 379],
#             [296, 379]]), 'i'), (array([[304, 363],
#             [317, 363],
#             [317, 379],
#             [304, 379]]), 's'), (array([[318, 359],
#             [333, 359],
#             [333, 379],
#             [318, 379]]), 'h'), (array([[335, 364],
#             [359, 364],
#             [359, 379],
#             [335, 379]]), 'm'), (array([[361, 365],
#             [375, 365],
#             [375, 380],
#             [361, 380]]), 'e'), (array([[377, 365],
#             [392, 365],
#             [392, 380],
#             [377, 380]]), 'n'), (array([[395, 361],
#             [403, 361],
#             [403, 381],
#             [395, 381]]), 't')], [(array([[436, 366],
#             [459, 366],
#             [459, 381],
#             [436, 381]]), 'm'), (array([[461, 366],
#             [475, 366],
#             [475, 381],
#             [461, 381]]), 'a'), (array([[477, 361],
#             [484, 361],
#             [484, 381],
#             [477, 381]]), 'i'), (array([[484, 366],
#             [499, 366],
#             [499, 381],
#             [484, 381]]), 'n'), (array([[502, 362],
#             [510, 362],
#             [510, 382],
#             [502, 382]]), 't'), (array([[511, 367],
#             [525, 367],
#             [525, 382],
#             [511, 382]]), 'e'), (array([[527, 367],
#             [542, 367],
#             [542, 382],
#             [527, 382]]), 'n'), (array([[544, 367],
#             [558, 367],
#             [558, 383],
#             [544, 383]]), 'a'), (array([[560, 367],
#             [575, 367],
#             [575, 382],
#             [560, 382]]), 'n'), (array([[577, 367],
#             [591, 367],
#             [591, 383],
#             [577, 383]]), 'c'), (array([[594, 367],
#             [607, 367],
#             [607, 383],
#             [594, 383]]), 'e')], [(array([[  0, 452],
#             [169, 452],
#             [169, 479],
#             [  0, 479]]), '')], [(array([[178, 461],
#             [249, 461],
#             [249, 479],
#             [178, 479]]), '')], [(array([[264, 473],
#             [352, 473],
#             [352, 479],
#             [264, 479]]), '')], [(array([[365, 466],
#             [639, 466],
#             [639, 479],
#             [365, 479]]), '')], [(array([[194, 363],
#             [205, 363],
#             [205, 374],
#             [194, 374]]), '')], [(array([[414, 368],
#             [425, 368],
#             [425, 379],
#             [414, 379]]), '')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/209.jpg',
#   [[(array([[ 69, 133],
#             [123, 133],
#             [123, 187],
#             [ 69, 187]]), 'N'), (array([[130, 149],
#             [171, 149],
#             [171, 189],
#             [130, 189]]), 'e'), (array([[176, 149],
#             [217, 149],
#             [217, 189],
#             [176, 189]]), 'e'), (array([[222, 131],
#             [265, 131],
#             [265, 189],
#             [222, 189]]), 'd')], [(array([[295, 150],
#             [338, 150],
#             [338, 190],
#             [295, 190]]), 'a')], [(array([[371, 135],
#             [413, 135],
#             [413, 189],
#             [371, 189]]), 'B'), (array([[421, 151],
#             [450, 151],
#             [450, 190],
#             [421, 190]]), 'r'), (array([[452, 151],
#             [493, 151],
#             [493, 191],
#             [452, 191]]), 'o'), (array([[500, 133],
#             [514, 133],
#             [514, 191],
#             [500, 191]]), 'l'), (array([[523, 134],
#             [537, 134],
#             [537, 191],
#             [523, 191]]), 'l'), (array([[541, 154],
#             [581, 154],
#             [581, 208],
#             [541, 208]]), 'y'), (array([[584, 135],
#             [620, 135],
#             [620, 193],
#             [584, 193]]), '?')], [(array([[ 67, 252],
#             [ 97, 252],
#             [ 97, 263],
#             [ 67, 263]]), '-')], [(array([[114, 221],
#             [157, 221],
#             [157, 285],
#             [114, 285]]), 'J'), (array([[153, 243],
#             [194, 243],
#             [194, 284],
#             [153, 284]]), 'u'), (array([[193, 243],
#             [232, 243],
#             [232, 285],
#             [193, 285]]), 's'), (array([[234, 227],
#             [264, 227],
#             [264, 285],
#             [234, 285]]), 't')], [(array([[280, 223],
#             [331, 223],
#             [331, 286],
#             [280, 286]]), 'A'), (array([[326, 245],
#             [366, 245],
#             [366, 287],
#             [326, 287]]), 's'), (array([[364, 227],
#             [404, 227],
#             [404, 287],
#             [364, 287]]), 'k'), (array([[405, 237],
#             [429, 237],
#             [429, 288],
#             [405, 288]]), '!')]],
#   1),
#  ('./icdar2013/Challenge2_Training_Task12_Images/273.jpg',
#   [[(array([[  8,  60],
#             [175,  60],
#             [175, 237],
#             [  8, 237]]), 'G'), (array([[183,  62],
#             [388,  62],
#             [388, 234],
#             [183, 234]]), 'Y'), (array([[390,  60],
#             [615,  60],
#             [615, 232],
#             [390, 232]]), 'M')]],
#   1)]

# %%
train, validation = sklearn.model_selection.train_test_split(
    dataset, train_size=0.8, random_state=42
)
augmenter = imgaug.augmenters.Sequential([
    imgaug.augmenters.Affine(
    scale=(1.0, 1.2),
    rotate=(-5, 5)
    ),
    imgaug.augmenters.GaussianBlur(sigma=(0, 0.5)),
    imgaug.augmenters.Multiply((0.8, 1.2), per_channel=0.2)
])
generator_kwargs = {'width': 640, 'height': 640}
training_image_generator = keras_ocr.datasets.get_detector_image_generator(
    labels=train,
    augmenter=augmenter,
    **generator_kwargs
)
validation_image_generator = keras_ocr.datasets.get_detector_image_generator(
    labels=validation,
    **generator_kwargs
)

# %%
image, lines, confidence = next(training_image_generator)
canvas = keras_ocr.tools.drawBoxes(image=image, boxes=lines, boxes_format='lines')
plt.imshow(canvas)

# %%
# detector = keras_ocr.detection.Detector()

# batch_size = 1
# training_generator, validation_generator = [
#     detector.get_batch_generator(
#         image_generator=image_generator, batch_size=batch_size
#     ) for image_generator in
#     [training_image_generator, validation_image_generator]
# ]
# detector.model.fit_generator(
#     generator=training_generator,
#     steps_per_epoch=math.ceil(len(train) / batch_size),
#     epochs=1000,
#     workers=0,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(restore_best_weights=True, patience=5),
#         tf.keras.callbacks.CSVLogger(os.path.join(data_dir, 'detector_icdar2013.csv')),
#         tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(data_dir, 'detector_icdar2013.h5'))
#     ],
#     validation_data=validation_generator,
#     validation_steps=math.ceil(len(validation) / batch_size)
# )

# %% [markdown]
# ##커스텀 데이터셋 리턴 포맷 맞추기
# ###리턴 타입 분석

# %%
type(dataset)
# Out:
# list

# %%
type(dataset[0][1][0][0])
# Out:
# tuple

# %%
dataset[0][1][0][0][0]
# Out:
# array([[1198, 1212],
#        [1330, 1212],
#        [1330, 1339],
#        [1198, 1339]])

# %%
type(dataset[0][1][0][0][0])
# Out:
# numpy.ndarray

# %%
dataset[0][1][0][0][0].shape
# Out:
# (4, 2)

# %% [markdown]
# ###커스텀데이터 다운로드

# %%
import os
import zipfile
import glob

CURR_PATH = os.getcwd()

os.listdir(CURR_PATH)
CUS_DATA_PATH = CURR_PATH + '/drive/MyDrive/Colab Notebooks/data_set/license_plate_detection_data.zip'
print("RAW_PATH", CUS_DATA_PATH)

with zipfile.ZipFile(CUS_DATA_PATH) as zfile:
  zfile.extractall(CURR_PATH)
# Out:
# RAW_PATH /content/drive/MyDrive/Colab Notebooks/data_set/license_plate_detection_data.zip

# %% [markdown]
# ###커스텀 데이터 전처리
# ####keras-ocr(get_icdar_2013_detector_dataset 함수)참고

# %%
# #기존 데이터셋 가져오는 함수 수정 필요
# def get_icdar_2013_detector_dataset(cache_dir=None, skip_illegible=False):
#     """Get the ICDAR 2013 text segmentation dataset for detector
#     training. Only the training set has the necessary annotations.
#     For the test set, only segmentation maps are provided, which
#     do not provide the necessary information for affinity scores.
#     Args:
#         cache_dir: The directory in which to store the data.
#         skip_illegible: Whether to skip illegible characters.
#     Returns:
#         Lists of (image_path, lines, confidence) tuples. Confidence
#         is always 1 for this dataset. We record confidence to allow
#         for future support for weakly supervised cases.
#     """
#     if cache_dir is None:
#         cache_dir = tools.get_default_cache_dir()
#     main_dir = os.path.join(cache_dir, "icdar2013")
#     training_images_dir = os.path.join(main_dir, "Challenge2_Training_Task12_Images")
    
# 		#데이터셋 이미지 압축파일 주소 설정
# 		training_zip_images_path = tools.download_and_verify(
#         url="https://github.com/faustomorales/keras-ocr/releases/download/v0.8.4/Challenge2_Training_Task12_Images.zip",  # pylint: disable=line-too-long
#         cache_dir=main_dir,
#         filename="Challenge2_Training_Task12_Images.zip",
#         sha256="7a57d1699fbb92db3ad82c930202938562edaf72e1c422ddd923860d8ace8ded",
#     )
		
# 		#데이터셋 이미지 압축 풀어서 229개 이미지 jpg 가져오기
#     if len(glob.glob(os.path.join(training_images_dir, "*.jpg"))) != 229:
#         with zipfile.ZipFile(training_zip_images_path) as zfile:
#             zfile.extractall(training_images_dir)

# 		#데이터셋 라벨 압축파일 주소 설정
#     training_gt_dir = os.path.join(main_dir, "Challenge2_Training_Task2_GT")
    
# 		#데이터셋 라벨 압축 풀어서 라벨데이터 txt 가져오기
# 		training_zip_gt_path = tools.download_and_verify(
#         url="https://github.com/faustomorales/keras-ocr/releases/download/v0.8.4/Challenge2_Training_Task2_GT.zip",  # pylint: disable=line-too-long
#         cache_dir=main_dir,
#         filename="Challenge2_Training_Task2_GT.zip",
#         sha256="4cedd5b1e33dc4354058f5967221ac85dbdf91a99b30f3ab1ecdf42786a9d027",
#     )
#     if len(glob.glob(os.path.join(training_gt_dir, "*.txt"))) != 229:
#         with zipfile.ZipFile(training_zip_gt_path) as zfile:
#             zfile.extractall(training_gt_dir)


#     dataset = []
#     for gt_filepath in glob.glob(os.path.join(training_gt_dir, "*.txt")):
#         image_id = os.path.split(gt_filepath)[1].split("_")[0]
#         image_path = os.path.join(training_images_dir, image_id + ".jpg")
#         lines = []
#         with open(gt_filepath, "r", encoding="utf8") as f:
#             current_line: typing.List[typing.Tuple[np.ndarray, str]] = []
#             for raw_row in f.read().split("\n"):
#                 if raw_row == "":
#                     lines.append(current_line)
#                     current_line = []
#                 else:
#                     row = raw_row.split(" ")[5:]
#                     character = row[-1][1:-1]
#                     if character == "" and skip_illegible:
#                         continue
#                     x1, y1, x2, y2 = map(int, row[:4])
#                     current_line.append(
#                         (np.array([[x1, y1], [x2, y1], [x2, y2], [x1, y2]]), character)
#                     )
#         # Some lines only have illegible characters and if skip_illegible is True,
#         # then these lines will be blank.
#         lines = [line for line in lines if line]
				
# 				#이미지 패스, 좌표값, 1(정답) 리턴
#         dataset.append((image_path, lines, 1))
#     return dataset

# %%
"""
ICDAR2013 데이터셋
array([[1198, 1212],
       [1330, 1212],
       [1330, 1339],
       [1198, 1339]])

license_plate_detection 데이터셋
335 294 448 294 448 350 335 350 "TVG399"
->
array([[335, 294],
       [448, 294],
       [448, 350],
       [335, 350]])
"""

# %%
def get_licenseplate_detector_dataset(current_dir=None):
  
  if current_dir is None:
    return ValueError('current_dir is None')

  main_dir = os.path.join(current_dir, 'license_plate_detection_data')
  training_images_dir = os.path.join(main_dir, "images")
  training_annot_dir = os.path.join(main_dir, "annotations")
	
  dataset = []

  for gt_list in glob.glob(os.path.join(training_annot_dir, '*.txt')):
    #print(gt_list)
    image_id = gt_list.split('/')[-1].split('.')[0]
    image_path = os.path.join(training_images_dir, image_id + '.jpg')
    #print(image_path)

    lines = []

    with open(gt_list, 'r') as f:
      for row in f.read().split('\n'):
        current_line = []
        character = row.split(' ')[-1][1:-1]
        row = row.split(' ')[:-1]
        
        x1, y1, x2, y2, x3, y3, x4, y4 = map(int, row[:8])
        current_line.append((np.array([[x1, y1], [x2, y2], [x3, y3], [x4, y4]]), character))
        lines.append(current_line)
        # print(lines[0])
    
    #if 조건에 해당하는 값만 출력
    # for line in lines:
    #   if line:
    #     line
    # = line for line in lines if line

    lines = [line for line in lines if line]
    dataset.append((image_path, lines, 1))

  return dataset

# %%
dataset = get_licenseplate_detector_dataset(current_dir='/content')
print(dataset[0])
# Out:
# ('/content/license_plate_detection_data/images/d4f79480-366a-40b6-ab2c-328bcba705b2.jpg', [[(array([[478, 336],
#        [549, 336],
#        [549, 371],
#        [478, 371]]), 'FB5X8T')]], 1)

# %% [markdown]
# ## Train 데이터 & Test 데이터 나누기

# %%
train, validation = sklearn.model_selection.train_test_split(
    dataset, train_size=0.8, random_state=42
)
augmenter = imgaug.augmenters.Sequential([
    imgaug.augmenters.Affine(
    scale=(1.0, 1.2),
    rotate=(-5, 5)
    ),
    imgaug.augmenters.GaussianBlur(sigma=(0, 0.5)),
    imgaug.augmenters.Multiply((0.8, 1.2), per_channel=0.2)
])
generator_kwargs = {'width': 640, 'height': 640}
training_image_generator = keras_ocr.datasets.get_detector_image_generator(
    labels=train,
    augmenter=augmenter,
    **generator_kwargs
)
validation_image_generator = keras_ocr.datasets.get_detector_image_generator(
    labels=validation,
    **generator_kwargs
)

# %%
image, lines, confidence = next(training_image_generator)
canvas = keras_ocr.tools.drawBoxes(image=image, boxes=lines, boxes_format='lines')
plt.imshow(canvas)

# %% [markdown]
# ##모델 학습

# %%
# !pwd
# Out:
# /content

# %%
detector = keras_ocr.detection.Detector()

#모델 가중치 저장
#기존에 학습시키던 모델 있으면 학습하는 코드
loading_model_path = os.path.join(CURR_PATH, '/drive/MyDrive/Colab Notebooks/craft_detector_carplate.h5')
if os.path.isfile(loading_model_path) == True:
  detector.model.load_weights(loading_model_path)
  print(loading_model_path + ' model loaded')
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Downloading /root/.keras-ocr/craft_mlt_25k.h5

# %%
#os.environ['TF_GPU_THREAD_MODE'] = 'gpu_private' # 추가
with tf.device('/device:GPU:0'):
  batch_size = 1
  training_generator, validation_generator = [
      detector.get_batch_generator(
          image_generator=image_generator, batch_size=batch_size
      ) for image_generator in
      [training_image_generator, validation_image_generator]
  ]
  detector.model.fit_generator(
      generator=training_generator,
      steps_per_epoch=math.ceil(len(train) / batch_size),
      epochs=1000,
      workers=0,
      callbacks=[
          tf.keras.callbacks.EarlyStopping(restore_best_weights=True, patience=5),
          
          #epoch별 로그변화 csv 파일 저장
          tf.keras.callbacks.CSVLogger(os.path.join(CURR_PATH, 'craft_detector_carplate.csv')),
          #epoch별 현재까지 학습된 모델 저장
          tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(CURR_PATH, 'craft_detector_carplate.h5'))
      ],
      validation_data=validation_generator,
      validation_steps=math.ceil(len(validation) / batch_size)
  )
# Out:
# Epoch 1/1000
#   1/177 [..............................] - ETA: 8s - loss: 1.6939e-04
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 177/177 [==============================] - 17s 99ms/step - loss: 2.0792e-04 - val_loss: 0.0024
# Epoch 2/1000
# 177/177 [==============================] - 18s 100ms/step - loss: 2.0708e-04 - val_loss: 0.0014
# Epoch 3/1000
# 177/177 [==============================] - 17s 99ms/step - loss: 2.6218e-04 - val_loss: 0.0011
# Epoch 4/1000
# 177/177 [==============================] - 17s 99ms/step - loss: 3.1637e-04 - val_loss: 5.8329e-04
# Epoch 5/1000
# 177/177 [==============================] - 18s 99ms/step - loss: 3.3705e-04 - val_loss: 5.5797e-04
# Epoch 6/1000
# 177/177 [==============================] - 17s 99ms/step - loss: 2.9562e-04 - val_loss: 6.3473e-04
# Epoch 7/1000
# 177/177 [==============================] - 18s 101ms/step - loss: 3.0136e-04 - val_loss: 4.2900e-04
# Epoch 8/1000
# 177/177 [==============================] - 18s 100ms/step - loss: 3.1263e-04 - val_loss: 5.4431e-04
# Epoch 9/1000
# 177/177 [==============================] - 17s 98ms/step - loss: 2.2976e-04 - val_loss: 4.7252e-04
# Epoch 10/1000
# 177/177 [==============================] - 17s 98ms/step - loss: 2.1194e-04 - val_loss: 5.0444e-04
# Epoch 11/1000
# 177/177 [==============================] - 17s 98ms/step - loss: 1.8778e-04 - val_loss: 0.0013
# Epoch 12/1000
# 177/177 [==============================] - 17s 98ms/step - loss: 2.5891e-04 - val_loss: 6.5610e-04

# %% [markdown]
# ###완료 모델(h5) 및 트레이닝 로그 PC 다운로드

# %%
#pc 저장
from google.colab import files
files.download('/content/craft_detector_carplate.h5')

# %%
#pc 저장
files.download('/content/craft_detector_carplate.csv')

# %%
# draw one sample training image for sanity check
image, lines, confidence = next(validation_image_generator)
canvas = keras_ocr.tools.drawBoxes(image=image, boxes=lines, boxes_format='lines')
plt.imshow(canvas)

# %%
# !mkdir craft_license_plate_validation_result

# %%
validation
# Out:
# [('/content/license_plate_detection_data/images/wts-lg-000027.jpg',
#   [[(array([[ 887,  205],
#             [1021,  205],
#             [1021,  272],
#             [ 887,  272]]), 'SG8L7E')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000068.jpg',
#   [[(array([[566, 452],
#             [625, 452],
#             [625, 481],
#             [566, 481]]), 'N359973')]],
#   1),
#  ('/content/license_plate_detection_data/images/us2.jpg', [[(array([[305, 232],
#             [417, 232],
#             [417, 288],
#             [305, 288]]), 'EUS664')]], 1),
#  ('/content/license_plate_detection_data/images/us1.jpg', [[(array([[501, 335],
#             [660, 335],
#             [660, 414],
#             [501, 414]]), '4PCI264')]], 1),
#  ('/content/license_plate_detection_data/images/wts-lg-000051.jpg',
#   [[(array([[756, 505],
#             [854, 505],
#             [854, 554],
#             [756, 554]]), 'PJ2X1V')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000012.jpg',
#   [[(array([[571, 283],
#             [691, 283],
#             [691, 343],
#             [571, 343]]), 'CK0A1F')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000026.jpg',
#   [[(array([[430, 109],
#             [525, 109],
#             [525, 156],
#             [430, 156]]), 'ML0C2S')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000087.jpg',
#   [[(array([[692, 583],
#             [790, 583],
#             [790, 632],
#             [692, 632]]), '383WJP')]],
#   1),
#  ('/content/license_plate_detection_data/images/car6.jpg',
#   [[(array([[285, 124],
#             [366, 124],
#             [366, 164],
#             [285, 164]]), 'AKS4329')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000086.jpg',
#   [[(array([[186, 219],
#             [285, 219],
#             [285, 268],
#             [186, 268]]), 'ATGL04')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000150.jpg',
#   [[(array([[495, 309],
#             [584, 309],
#             [584, 353],
#             [495, 353]]), '6WHS906')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000049.jpg',
#   [[(array([[646, 326],
#             [720, 326],
#             [720, 363],
#             [646, 363]]), 'WG4L2M')]],
#   1),
#  ('/content/license_plate_detection_data/images/us6.jpg', [[(array([[383, 568],
#             [599, 568],
#             [599, 676],
#             [383, 676]]), 'HL0KTY1')]], 1),
#  ('/content/license_plate_detection_data/images/wts-lg-000142.jpg',
#   [[(array([[260, 436],
#             [357, 436],
#             [357, 484],
#             [260, 484]]), '5TGN556')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000062.jpg',
#   [[(array([[662, 520],
#             [744, 520],
#             [744, 561],
#             [662, 561]]), 'GT679A')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000193.jpg',
#   [[(array([[495, 424],
#             [639, 424],
#             [639, 496],
#             [495, 496]]), 'RZN384')]],
#   1),
#  ('/content/license_plate_detection_data/images/us7.jpg', [[(array([[344, 210],
#             [637, 210],
#             [637, 356],
#             [344, 356]]), '5VCF203')]], 1),
#  ('/content/license_plate_detection_data/images/wts-lg-000010.jpg',
#   [[(array([[464, 440],
#             [579, 440],
#             [579, 497],
#             [464, 497]]), 'HH9G5W')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000073.jpg',
#   [[(array([[1010,  337],
#             [1104,  337],
#             [1104,  384],
#             [1010,  384]]), '5VDA555')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000070.jpg',
#   [[(array([[627, 496],
#             [737, 496],
#             [737, 551],
#             [627, 551]]), 'WXY184')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000069.jpg',
#   [[(array([[748, 592],
#             [829, 592],
#             [829, 632],
#             [748, 632]]), 'TWF220')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000194.jpg',
#   [[(array([[859,   8],
#             [942,   8],
#             [942,  49],
#             [859,  49]]), '7CID930')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000166.jpg',
#   [[(array([[501, 109],
#             [577, 109],
#             [577, 147],
#             [501, 147]]), '4NZZ935')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000097.jpg',
#   [[(array([[617, 553],
#             [707, 553],
#             [707, 598],
#             [617, 598]]), 'R589789')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000042.jpg',
#   [[(array([[ 35, 463],
#             [107, 463],
#             [107, 499],
#             [ 35, 499]]), 'SK5K9V')]],
#   1),
#  ('/content/license_plate_detection_data/images/us5.jpg',
#   [[(array([[ 841,  666],
#             [1068,  666],
#             [1068,  779],
#             [ 841,  779]]), 'NEILDMND')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000064.jpg',
#   [[(array([[442, 424],
#             [538, 424],
#             [538, 472],
#             [442, 472]]), 'UH1N2A')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000123.jpg',
#   [[(array([[638, 293],
#             [724, 293],
#             [724, 336],
#             [638, 336]]), '6XIU641')]],
#   1),
#  ('/content/license_plate_detection_data/images/us4.jpg', [[(array([[ 65,  54],
#             [221,  54],
#             [221, 132],
#             [ 65, 132]]), '520MRK')]], 1),
#  ('/content/license_plate_detection_data/images/wts-lg-000053.jpg',
#   [[(array([[598, 453],
#             [665, 453],
#             [665, 486],
#             [598, 486]]), 'TNP222')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000047.jpg',
#   [[(array([[573, 238],
#             [629, 238],
#             [629, 266],
#             [573, 266]]), 'CLT0108')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000174.jpg',
#   [[(array([[442, 281],
#             [533, 281],
#             [533, 326],
#             [442, 326]]), '5BDE732')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000096.jpg',
#   [[(array([[237, 238],
#             [317, 238],
#             [317, 278],
#             [237, 278]]), 'CJ1P5G')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000181.jpg',
#   [[(array([[606, 417],
#             [723, 417],
#             [723, 475],
#             [606, 475]]), 'PH5M9Y')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000168.jpg',
#   [[(array([[317, 521],
#             [480, 521],
#             [480, 602],
#             [317, 602]]), 'RZN384')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000074.jpg',
#   [[(array([[ 914,  314],
#             [1034,  314],
#             [1034,  374],
#             [ 914,  374]]), 'AG6V1W')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000099.jpg',
#   [[(array([[327, 284],
#             [410, 284],
#             [410, 325],
#             [327, 325]]), 'UG9L8U')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000091.jpg',
#   [[(array([[604, 124],
#             [668, 124],
#             [668, 156],
#             [604, 156]]), 'MJ3R1V')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000115.jpg',
#   [[(array([[280, 557],
#             [417, 557],
#             [417, 625],
#             [280, 625]]), 'HH9G5W')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000144.jpg',
#   [[(array([[660, 323],
#             [800, 323],
#             [800, 393],
#             [660, 393]]), 'CWW2245')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000155.jpg',
#   [[(array([[795, 291],
#             [924, 291],
#             [924, 355],
#             [795, 355]]), 'CYZ5139')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000045.jpg',
#   [[(array([[273, 318],
#             [352, 318],
#             [352, 357],
#             [273, 357]]), 'HF4Y3B')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000075.jpg',
#   [[(array([[800, 401],
#             [895, 401],
#             [895, 448],
#             [800, 448]]), '6LKR481')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000117.jpg',
#   [[(array([[713, 498],
#             [811, 498],
#             [811, 547],
#             [713, 547]]), 'D315771')]],
#   1),
#  ('/content/license_plate_detection_data/images/wts-lg-000173.jpg',
#   [[(array([[651, 234],
#             [734, 234],
#             [734, 275],
#             [651, 275]]), '5FEE732')]],
#   1)]

# %% [markdown]
# ### 모델 loadiing

# %%
# Previous to this assume you've trained a recognizer.
detector.model.save_weights('/content/drive/MyDrive/Colab Notebooks/craft_detector_carplate.h5')

# Let's reload the recognizer. First, instantiate a recognizer with the *same*
# arguments as those you used earlier (e.g., alphabet).
reloaded_detector = keras_ocr.detection.Detector()

# Now load the weights you saved earlier.
reloaded_detector.model.load_weights('/content/drive/MyDrive/Colab Notebooks/craft_detector_carplate.h5')
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5

# %%
import imageio
import cv2

output_folder = 'craft_license_plate_validation_result'

for image_path, _, _ in validation:
  image = keras_ocr.tools.read(image_path)

  output_image_path = os.path.join(output_folder, image_path.split('/')[-1])

  # detector prediction
  pred_boxes = reloaded_detector.detect(np.expand_dims(image, axis=0))
  #print(pred_boxes)

  for each_pred in pred_boxes[0]:
    left, top = each_pred[0]
    right, bottom = each_pred[2]
    print(left, top, right, bottom)
    canvas = cv2.rectangle(image, (int(left), int(top)), (int(right), int(bottom)), (0,255,0), 3)

  imageio.imwrite(output_image_path, canvas) 
  print(output_image_path + ' saved!' )
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 2.0 4.0 124.0 18.0
# 1160.4309 126.553856 1199.1694 146.64615
# 892.0 220.0 950.0 260.0
# 974.0 224.0 1014.0 264.0
# 914.0 262.0 954.0 274.0
# 1210.0 700.0 1252.0 710.0
# 1222.0 710.0 1258.0 718.0
# craft_license_plate_validation_result/wts-lg-000027.jpg saved!
# 1/1 [==============================] - 0s 23ms/step
# 4.0 4.0 72.0 18.0
# 74.0 4.0 124.0 18.0
# 566.1056 457.5698 623.69434 483.03018
# 730.0 480.0 778.0 488.0
# 742.0 490.0 790.0 498.0
# craft_license_plate_validation_result/wts-lg-000068.jpg saved!
# 1/1 [==============================] - 0s 23ms/step
# 499.61896 214.09158 578.42255 224.98373
# 308.0 246.0 414.0 278.0
# craft_license_plate_validation_result/us2.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 506.0 360.0 652.0 402.0
# 992.0 626.0 1070.0 658.0
# 1070.0 694.0 1106.0 712.0
# 1108.0 696.0 1244.0 712.0
# 1242.0 700.0 1276.0 712.0
# craft_license_plate_validation_result/us1.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 4.0 4.0 52.0 18.0
# 74.0 4.0 118.0 18.0
# 676.0 8.0 790.0 36.0
# 278.0 152.0 308.0 162.0
# 756.9296 513.2428 853.1181 541.9552
# 1210.0 780.0 1234.0 790.0
# 1236.0 780.0 1258.0 788.0
# 1258.0 780.0 1272.0 790.0
# 1222.0 790.0 1270.0 798.0
# craft_license_plate_validation_result/wts-lg-000051.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 570.0 294.0 684.0 332.0
# craft_license_plate_validation_result/wts-lg-000012.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# -4.286264e-16 4.0 38.0 18.0
# 36.0 4.0 72.0 18.0
# 72.0 4.0 124.0 18.0
# 427.11362 123.946396 529.12305 144.02525
# 1236.0 702.0 1252.0 708.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000026.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 36.0 4.0 62.0 18.0
# 74.0 4.0 124.0 18.0
# 60.0 6.0 72.0 18.0
# 1210.0 698.0 1254.0 712.0
# 1222.0 708.0 1270.0 716.0
# craft_license_plate_validation_result/wts-lg-000087.jpg saved!
# 1/1 [==============================] - 0s 297ms/step
# 62.0 32.0 118.0 52.0
# 37.17362 50.117706 148.7289 87.88466
# craft_license_plate_validation_result/car6.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 2.0 4.0 38.0 18.0
# 36.0 4.0 124.0 18.0
# 1210.0 700.0 1272.0 718.0
# craft_license_plate_validation_result/wts-lg-000086.jpg saved!
# 1/1 [==============================] - 0s 39ms/step
# 494.0 322.0 586.0 358.0
# craft_license_plate_validation_result/wts-lg-000150.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 2.0 4.0 34.0 18.0
# 36.0 4.0 56.0 18.0
# 60.0 4.0 72.0 18.0
# 72.0 4.0 124.0 18.0
# 646.0 326.0 724.0 360.0
# 1258.0 698.0 1272.0 712.0
# 1210.0 700.0 1258.0 710.0
# 1222.0 710.0 1252.0 718.0
# 1258.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000049.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 208.0 414.0 292.0 428.0
# 298.0 416.0 326.0 428.0
# 309.89264 430.22168 406.24738 454.79346
# 396.0 598.0 474.0 658.0
# 482.0 600.0 584.0 658.0
# craft_license_plate_validation_result/us6.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 450.0 112.0 494.0 126.0
# 276.0 358.0 324.0 380.0
# 260.0 448.0 352.0 488.0
# craft_license_plate_validation_result/wts-lg-000142.jpg saved!
# 1/1 [==============================] - 0s 29ms/step
# 706.0 0.0 734.0 14.0
# 4.0 6.0 54.0 18.0
# 681.0227 529.47516 742.94116 553.76483
# 1162.0 592.0 1272.0 630.0
# 1150.0 632.0 1278.0 672.0
# 1210.0 698.0 1258.0 712.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000062.jpg saved!
# 1/1 [==============================] - 0s 29ms/step
# 728.0 0.0 778.0 32.0
# 678.0 0.0 718.0 32.0
# 834.0 316.0 924.0 344.0
# 211.72409 326.0658 364.36014 351.40985
# 574.0 442.0 632.0 480.0
# 500.0 444.0 558.0 482.0
# craft_license_plate_validation_result/wts-lg-000193.jpg saved!
# 1/1 [==============================] - 0s 24ms/step
# 354.0 216.0 396.0 244.0
# 402.0 214.0 574.0 258.0
# 630.0 244.0 710.0 328.0
# 361.3219 261.1761 624.9917 349.4029
# craft_license_plate_validation_result/us7.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 746.0 92.0 826.0 120.0
# 464.0 448.0 520.0 486.0
# 526.0 450.0 580.0 488.0
# craft_license_plate_validation_result/wts-lg-000010.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 52.0 18.0
# 56.0 4.0 124.0 18.0
# 1012.0 350.0 1100.0 380.0
# 1258.0 698.0 1272.0 718.0
# 1210.0 700.0 1254.0 710.0
# 1222.0 710.0 1256.0 718.0
# craft_license_plate_validation_result/wts-lg-000073.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 36.0 4.0 58.0 18.0
# 74.0 4.0 124.0 18.0
# 685.01544 508.12314 735.01544 532.12305
# 629.51996 516.64 681.5999 541.19995
# 817.74164 539.0952 926.6744 539.282
# 474.15384 582.7693 520.1538 588.7693
# 450.672 600.3803 571.36664 603.95807
# 1210.0 698.0 1254.0 712.0
# 1222.0 710.0 1240.0 716.0
# 1240.0 710.0 1270.0 716.0
# craft_license_plate_validation_result/wts-lg-000070.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 36.0 4.0 72.0 18.0
# 74.0 4.0 124.0 18.0
# 752.0 598.0 786.0 620.0
# 792.0 598.0 828.0 626.0
# 1208.0 700.0 1236.0 712.0
# 1234.0 700.0 1252.0 708.0
# 1222.0 700.0 1272.0 718.0
# craft_license_plate_validation_result/wts-lg-000069.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 864.29346 23.49488 935.9249 38.36177
# craft_license_plate_validation_result/wts-lg-000194.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 630.0 90.0 660.0 98.0
# 502.0 120.0 576.0 146.0
# craft_license_plate_validation_result/wts-lg-000166.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 34.0 18.0
# 36.0 4.0 62.0 18.0
# 74.0 4.0 98.0 18.0
# 96.0 4.0 124.0 18.0
# 888.0 238.0 960.0 264.0
# 950.0 250.0 980.0 264.0
# 892.0 308.0 948.0 320.0
# 890.0 312.0 982.0 330.0
# 620.0 568.0 656.0 594.0
# 660.0 570.0 706.0 596.0
# 1210.0 700.0 1236.0 710.0
# 1234.0 700.0 1252.0 708.0
# 1222.0 710.0 1240.0 718.0
# 1240.0 710.0 1258.0 718.0
# 1258.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000097.jpg saved!
# 1/1 [==============================] - 0s 23ms/step
# 8.0 4.0 38.0 18.0
# 40.0 4.0 74.0 18.0
# 72.0 4.0 108.0 18.0
# 110.0 4.0 160.0 18.0
# 48.0 470.0 104.0 492.0
# 730.0 580.0 756.0 592.0
# 754.0 580.0 772.0 588.0
# 760.0 590.0 778.0 596.0
# craft_license_plate_validation_result/wts-lg-000042.jpg saved!
# 1/1 [==============================] - 0s 42ms/step
# 852.0 696.0 908.0 754.0
# 902.0 698.0 1052.0 758.0
# 504.1989 739.03424 621.86615 768.6818
# 862.0 762.0 910.0 776.0
# 910.0 762.0 944.0 778.0
# 946.0 762.0 1016.0 780.0
# 1014.0 762.0 1054.0 780.0
# 1256.1279 765.60254 1403.8535 791.317
# craft_license_plate_validation_result/us5.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 4.0 4.0 64.0 18.0
# 62.0 4.0 70.0 16.0
# 72.0 4.0 122.0 18.0
# 482.0 428.0 538.0 460.0
# 444.0 434.0 480.0 466.0
# 1210.0 780.0 1236.0 792.0
# 1236.0 780.0 1252.0 788.0
# 1222.0 790.0 1240.0 798.0
# 1240.0 790.0 1258.0 796.0
# craft_license_plate_validation_result/wts-lg-000064.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 642.0 306.0 720.0 334.0
# craft_license_plate_validation_result/wts-lg-000123.jpg saved!
# 1/1 [==============================] - 0s 21ms/step
# 102.27077 59.126156 191.50154 84.972305
# 74.0 64.0 94.0 78.0
# 198.0 68.0 216.0 80.0
# 72.0 80.0 136.0 120.0
# 154.0 80.0 218.0 120.0
# 124.0 120.0 178.0 128.0
# craft_license_plate_validation_result/us4.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 36.0 4.0 72.0 18.0
# 74.0 4.0 124.0 18.0
# 630.0 458.0 664.0 478.0
# 600.0 460.0 630.0 480.0
# 1210.0 700.0 1252.0 708.0
# 1258.0 700.0 1270.0 708.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000053.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 36.0 4.0 58.0 18.0
# 56.0 4.0 72.0 18.0
# 74.0 4.0 124.0 18.0
# 4.0 6.0 34.0 18.0
# 572.0 244.0 628.0 262.0
# 1210.0 700.0 1252.0 708.0
# 1258.0 700.0 1270.0 708.0
# 1240.0 710.0 1256.0 718.0
# craft_license_plate_validation_result/wts-lg-000047.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 597.7031 261.468 648.2722 267.98758
# 447.2376 298.08124 532.8487 328.85736
# craft_license_plate_validation_result/wts-lg-000174.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 56.0 18.0
# 236.80002 236.40002 315.47586 280.28967
# 1210.0 698.0 1254.0 712.0
# 1222.0 700.0 1274.0 718.0
# craft_license_plate_validation_result/wts-lg-000096.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 608.0 426.0 662.0 464.0
# 666.0 428.0 718.0 464.0
# craft_license_plate_validation_result/wts-lg-000181.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 698.0 400.0 798.0 428.0
# -8.572528e-16 410.0 170.0 438.0
# 322.46185 544.1609 389.5423 581.92993
# 408.0 542.0 470.0 582.0
# craft_license_plate_validation_result/wts-lg-000168.jpg saved!
# 1/1 [==============================] - 0s 26ms/step
# 2.0 4.0 72.0 18.0
# 73.41378 6.0344806 122.62069 16.551727
# 911.12976 324.1522 1030.841 358.91122
# 1210.0 698.0 1236.0 712.0
# 1234.0 700.0 1252.0 708.0
# 1258.0 700.0 1270.0 708.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000074.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 2.0 4.0 32.0 18.0
# 36.0 6.0 52.0 16.0
# 328.0 290.0 410.0 320.0
# 1210.0 700.0 1252.0 710.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000099.jpg saved!
# 1/1 [==============================] - 0s 24ms/step
# 4.0 4.0 72.0 18.0
# 74.0 4.0 124.0 18.0
# 954.0 618.0 998.0 632.0
# 966.0 630.0 1014.0 638.0
# craft_license_plate_validation_result/wts-lg-000091.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 748.0 94.0 824.0 118.0
# 280.0 566.0 344.0 610.0
# 352.0 568.0 414.0 612.0
# craft_license_plate_validation_result/wts-lg-000115.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 998.0 0.0 1108.0 24.0
# 1196.0 24.0 1246.0 50.0
# 1192.0 70.0 1250.0 96.0
# 702.0 328.0 760.0 346.0
# 664.35156 346.6408 793.8727 388.83875
# craft_license_plate_validation_result/wts-lg-000144.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 832.0 290.0 886.0 310.0
# 558.0 310.0 588.0 318.0
# 798.0 310.0 920.0 346.0
# 666.0 320.0 724.0 334.0
# 652.0 338.0 748.0 356.0
# 868.0 344.0 916.0 358.0
# 804.0 346.0 864.0 358.0
# craft_license_plate_validation_result/wts-lg-000155.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 36.0 4.0 70.0 18.0
# 72.0 4.0 124.0 18.0
# 272.0 326.0 350.0 352.0
# 954.0 620.0 978.0 628.0
# 980.0 620.0 996.0 628.0
# 966.0 630.0 1002.0 638.0
# 1002.0 630.0 1014.0 638.0
# craft_license_plate_validation_result/wts-lg-000045.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 2.0 4.0 106.0 18.0
# 106.0 2.0 124.0 18.0
# 804.0 414.0 890.0 444.0
# 1210.0 700.0 1236.0 712.0
# 1222.0 700.0 1272.0 718.0
# craft_license_plate_validation_result/wts-lg-000075.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 4.0 4.0 38.0 18.0
# 56.0 4.0 72.0 18.0
# 74.0 4.0 122.0 18.0
# 36.0 6.0 54.0 18.0
# 712.0 510.0 754.0 540.0
# 756.0 514.0 808.0 542.0
# 1210.0 700.0 1234.0 708.0
# 1258.0 700.0 1272.0 710.0
# 1222.0 710.0 1270.0 718.0
# craft_license_plate_validation_result/wts-lg-000117.jpg saved!
# 1/1 [==============================] - 0s 25ms/step
# 652.13855 245.56686 733.86145 280.4332
# craft_license_plate_validation_result/wts-lg-000173.jpg saved!

# %%
# !zip -r /content/craft_license_plate_validation_result.zip /content/craft_license_plate_validation_result

# %%
from google.colab import files
files.download("/content/craft_license_plate_validation_result.zip")

# %% [markdown]
# # Google drive mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
